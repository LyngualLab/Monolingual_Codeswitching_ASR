# %%
# %%capture

"""
You can run either this notebook locally (if you have all the dependencies and a GPU) or on Google Colab.

Instructions for setting up Colab are as follows:
1. Open a new Python 3 notebook.
2. Import this notebook from GitHub (File -> Upload Notebook -> "GITHUB" tab -> copy/paste GitHub URL)
3. Connect to an instance with a GPU (Runtime -> Change runtime type -> select "GPU" for hardware accelerator)
4. Run this cell to set up dependencies.
5. Restart the runtime (Runtime -> Restart Runtime) for any upgraded packages to take effect


NOTE: User is responsible for checking the content of datasets and the applicable licenses and determining if suitable for the intended use.
"""

# Install dependencies
# !pip install wget
# !apt-get install sox libsndfile1 ffmpeg libsox-fmt-mp3
# !pip install text-unidecode
# !pip install matplotlib>=3.3.2
# !pip install datasets==2.21.0 # downgrading to 2.21.0 because latest version (3.0.0) has some issues
# !pip install wandb


## Install NeMo
BRANCH = 'main'
# !python -m pip install git+https://github.com/NVIDIA/NeMo.git@$BRANCH#egg=nemo_toolkit[all]

"""
Remember to restart the runtime for the kernel to pick up any upgraded packages (e.g. matplotlib)!
Alternatively, you can uncomment the exit() below to crash and restart the kernel, in the case
that you want to use the "Run All Cells" (or similar) option.
"""
# exit()

# %%
import os
import glob
import subprocess
import tarfile
import wget
import copy
from omegaconf import OmegaConf, open_dict
import nemo
import nemo.collections.asr as nemo_asr
from nemo.collections.asr.metrics.wer import word_error_rate
from nemo.utils import logging, exp_manager
from tqdm.auto import tqdm
from nemo.collections.asr.parts.utils.manifest_utils import read_manifest, write_manifest
import json
import wandb

# %%
wandb.login(key="56ba8228c7e8cf3c2c6037b966edc1cec69cc4a3")
wandb.init(project='CodeSwitch ASR')
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: olufemi. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.19.1
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250131_063302-rvcsgaj8
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run blooming-sun-13
# wandb: ⭐️ View project at https://wandb.ai/olufemi/CodeSwitch%20ASR
# wandb: 🚀 View run at https://wandb.ai/olufemi/CodeSwitch%20ASR/runs/rvcsgaj8
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/olufemi/CodeSwitch%20ASR/runs/rvcsgaj8?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
import pandas as pd
data = pd.read_csv("/kaggle/input/codeswitched-dataset/21 hours.csv")
data = data[["Prompt_text", "Duration", "full_audio_path"]]
data["full_audio_path"] = ["/kaggle/input/codeswitchedaudiofiles/audio_files/" + i for i in data["full_audio_path"]]
data
# Out:
#                                              Prompt_text  Duration  \
# 0         Àwọn challenges kan face mi, èmi náà face wọn.      4.56
# 1       My aunt always says, ‘Ìbáṣepọ̀rere ní ń mú ẹb...      2.22
# 2      Me that have been praying pe ki aye é le da, y...      4.14
# 3                                   Jọ lend me your pen.      1.80
# 4       My uncle always says, ‘Ìjọpọ̀ẹbí ń mú gbogbo ...      3.54
# ...                                                  ...       ...
# 16378  They would have been really punished tí Mọ bá ...      3.84
# 16379     Their blanket tí dà ná; where did they put it?      4.80
# 16380                      I didn't go anywhere pẹ̀lú ẹ.      2.82
# 16381    We want to go and buy water ní Baṣọ̀run market.      3.42
# 16382  The Yorùbá believe pé àbíkú child exists ní cr...      6.06
#
#                                          full_audio_path
# 0      /kaggle/input/codeswitchedaudiofiles/audio_fil...
# 1      /kaggle/input/codeswitchedaudiofiles/audio_fil...
# 2      /kaggle/input/codeswitchedaudiofiles/audio_fil...
# 3      /kaggle/input/codeswitchedaudiofiles/audio_fil...
# 4      /kaggle/input/codeswitchedaudiofiles/audio_fil...
# ...                                                  ...
# 16378  /kaggle/input/codeswitchedaudiofiles/audio_fil...
# 16379  /kaggle/input/codeswitchedaudiofiles/audio_fil...
# 16380  /kaggle/input/codeswitchedaudiofiles/audio_fil...
# 16381  /kaggle/input/codeswitchedaudiofiles/audio_fil...
# 16382  /kaggle/input/codeswitchedaudiofiles/audio_fil...
#
# [16383 rows x 3 columns]

# %%
import pandas as pd
import json
import os
import re
import string

def clean_text(text):
    """
    Cleans text by removing punctuation (except apostrophes), converting to lowercase,
    and stripping extra spaces.
    
    Args:
        text (str): The input text to clean.
    
    Returns:
        str: The cleaned text.
    """
    if not isinstance(text, str):
        return ""  # Handle cases where text is not a string
    
    # Keep only apostrophes, remove other punctuation
    text = re.sub(r"[{}]".format(re.escape(string.punctuation.replace("'", ""))), "", text)
    
    # Convert to lowercase
    text = text.lower()
    
    # Remove multiple spaces
    text = re.sub(r"\s+", " ", text).strip()
    
    return text

# %%
import json

# Define the output manifest file
output_manifest = "nemo_asr_manifest.json"

# Convert DataFrame to NeMo manifest format
with open(output_manifest, "w", encoding="utf-8") as f:
    for _, row in data.iterrows():
        manifest_entry = {
            "audio_filepath": row["full_audio_path"],
            "duration": row["Duration"],
            "text": clean_text(row["Prompt_text"])
        }
        json.dump(manifest_entry, f, ensure_ascii=False)
        f.write("\n")

print(f"NeMo ASR manifest saved to {output_manifest}")
# Out:
# NeMo ASR manifest saved to nemo_asr_manifest.json

# %%
# data = "/kaggle/working/nemo_asr_manifest.json"

# %%
# manifest_data = read_manifest(data)

# %%
# text = [data['text'] for data in manifest_data]

# %%
# with open('text.txt', 'w') as f:
#     for text in text:
#         f.write(text + '\n')

# %%
clean_text("My mother says, 'Ìdílé wa ní agbára àti ìmọ")
# Out:
# "my mother says 'ìdílé wa ní agbára àti ìmọ"

# %%
import pandas as pd
import json
import os

def convert_csv_to_nemo_manifest(csv_file):
    """
    Converts a CSV file to a NeMo ASR-compatible JSON manifest file.
    
    Args:
        csv_file (str): Path to the input CSV file.

    Saves:
        A JSON manifest file with the same name as the input CSV.
    """
    # Load the CSV file
    data = pd.read_csv(csv_file)
    data["full_audio_path"] = ["/kaggle/input/codeswitchedaudiofiles/audio_files/" + i for i in data["full_audio_path"]]

    # Extract filename without extension
    base_name = os.path.splitext(csv_file)[0]
    base_name = base_name.split("/")[-1]
    output_manifest = f"{base_name}.json"

    # Convert DataFrame to NeMo manifest format
    with open(output_manifest, "w", encoding="utf-8") as f:
        for _, row in data.iterrows():
            manifest_entry = {
                "audio_filepath": row["full_audio_path"],
                "duration": row["Duration"],
                "text": clean_text(row["Prompt_text"])
            }
            json.dump(manifest_entry, f, ensure_ascii=False)
            f.write("\n")

    print(f"NeMo ASR manifest saved to {output_manifest}")

# %%
# Example usage:
convert_csv_to_nemo_manifest("/kaggle/input/codeswitched-dataset/train.csv")
convert_csv_to_nemo_manifest("/kaggle/input/codeswitched-dataset/validation.csv")
convert_csv_to_nemo_manifest("/kaggle/input/codeswitched-dataset/test.csv")
# Out:
# NeMo ASR manifest saved to train.json
# NeMo ASR manifest saved to validation.json
# NeMo ASR manifest saved to test.json

# %%
# import re
# from tqdm import tqdm
# import os

# chars_to_ignore_regex = r'[,\?\.\!\-\;\:\"“%\‘”�…{}\[\]・。『』、ー〜]'  # Regex to remove unwanted characters

# def remove_special_characters(data):
#     """Clean unwanted characters and convert text to lowercase."""
#     data["text"] = re.sub(chars_to_ignore_regex, '', data["text"]).lower().strip()
#     return data

# def apply_preprocessors(manifest):
#     """
#     Apply `remove_special_characters` to each entry in the manifest.

#     Args:
#         manifest (list[dict]): List of data entries with a 'text' field.

#     Returns:
#         list[dict]: Preprocessed manifest.
#     """
#     for idx in tqdm(range(len(manifest)), desc="Applying remove_special_characters"):
#         manifest[idx] = remove_special_characters(manifest[idx])
#     print("Finished processing manifest!")
#     return manifest

# def write_processed_manifest(data, original_path):
#     """
#     Write the preprocessed manifest to a new file.

#     Args:
#         data (list[dict]): Processed manifest data.
#         original_path (str): Path to the original file.

#     Returns:
#         str: Path to the new processed manifest file.
#     """
#     base, ext = os.path.splitext(original_path)
#     new_manifest_name = f"{base}_processed{ext}"
#     write_manifest(new_manifest_name, data)
#     print(f"Finished writing manifest: {new_manifest_name}")
#     return new_manifest_name

# %%
# data_ = read_manifest(data)
# data_processed = apply_preprocessors(data_)

# # Write new manifests
# manifest_cleaned = write_processed_manifest(data_processed, data)

# %%
# import json
# import random

# # Input file
# input_file = data

# # Output files
# train_file = "train.json"
# validation_file = "validation.json"
# test_file = "test.json"

# # Split ratios
# train_ratio = 0.8
# validation_ratio = 0.1
# test_ratio = 0.1

# # Load the data
# with open(input_file, "r") as f:
#     data = [json.loads(line) for line in f]

# # Shuffle the data
# random.shuffle(data)

# # Calculate split indices
# total_samples = len(data)
# train_end = int(total_samples * train_ratio)
# validation_end = train_end + int(total_samples * validation_ratio)

# # Split the data
# train_data = data[:train_end]
# validation_data = data[train_end:validation_end]
# test_data = data[validation_end:]

# # Save the splits
# with open(train_file, "w") as f:
#     for item in train_data:
#         f.write(json.dumps(item) + "\n")

# with open(validation_file, "w") as f:
#     for item in validation_data:
#         f.write(json.dumps(item) + "\n")

# with open(test_file, "w") as f:
#     for item in test_data:
#         f.write(json.dumps(item) + "\n")

# print(f"Data successfully split!\nTrain: {len(train_data)}\nValidation: {len(validation_data)}\nTest: {len(test_data)}")


# train='train.json'
# validation='validation.json'
# test='test.json'

# %%
pd.read_csv("/kaggle/input/codeswitched-dataset/train.csv").head()
# Out:
#                      Fullname                  Email_Address  \
# 0       Odeyemi Tosin Solomon        huntertosin96@gmail.com
# 1         OJO OLAOLUWA VICTOR   olaoluwavictor2019@gmail.com
# 2  Saoban Ramotallahi Olamide  saobanramotallahi08@gmail.com
# 3             Lateefat Saoban      saobanlateefat1@gmail.com
# 4         OJO OLAOLUWA VICTOR   olaoluwavictor2019@gmail.com
#
#                   Prompt_ID  \
# 0  67802cba7a251edbd6a920bd
# 1  677595d209f2f37dcccafd5c
# 2  677027b7f324631b7d83965a
# 3  677fb54584b0c362d5ec07f0
# 4  6780a2c484b0c362d5295843
#
#                                          Prompt_text Prompt_type  \
# 0          I want to read iwe ti mo ra ni last week.      Prompt
# 1     E update your system? It will fix most issues.      Prompt
# 2  Lola was doing Alajapa work before she wo ise ...      Prompt
# 3  My oluko inspires me daily to be a better pers...      Prompt
# 4   My mother says, ‘Ìdílé wa ní agbára àti ìmọ̀t...      Prompt
#
#                                           Audio_link  Duration  \
# 0  https://storage.googleapis.com/transcribeme-ly...      3.06
# 1  https://storage.googleapis.com/transcribeme-ly...      3.78
# 2  https://storage.googleapis.com/transcribeme-ly...      6.66
# 3  https://storage.googleapis.com/transcribeme-ly...      5.04
# 4  https://storage.googleapis.com/transcribeme-ly...      3.78
#
#                 full_audio_path
# 0  67802cba7a251edbd6a920bd.wav
# 1  677595d209f2f37dcccafd5c.wav
# 2  677027b7f324631b7d83965a.wav
# 3  677fb54584b0c362d5ec07f0.wav
# 4  6780a2c484b0c362d5295843.wav

# %%
import json
files = ["train.json", "validation.json", "test.json"]

for file in files:
    with open(file, "r") as f:
        for i, line in enumerate(f):
            try:
                json.loads(line)
            except Exception as e:
                print(f"Error in {file}, line {i}: {e}")

# %%
import os
import json
from pydub import AudioSegment
from concurrent.futures import ThreadPoolExecutor
from tqdm import tqdm

def resample_audio(input_path, output_path, target_sample_rate=16000):
    try:
        audio = AudioSegment.from_file(input_path)
        audio = audio.set_frame_rate(target_sample_rate).set_channels(1)
        audio.export(output_path, format="wav")
    except Exception as e:
        print(f"Error processing {input_path}: {e}")

def batch_resample_parallel(manifest_paths, output_dir, target_sample_rate=16000, max_workers=4):
    os.makedirs(output_dir, exist_ok=True)

    # Combine all manifests into a single list of tasks
    tasks = []
    for manifest_path in manifest_paths:
        with open(manifest_path, "r") as f:
            lines = [json.loads(line) for line in f]
            for item in lines:
                input_audio = item["audio_filepath"]
                output_audio = os.path.join(output_dir, os.path.basename(input_audio))
                tasks.append((input_audio, output_audio, target_sample_rate))

    # Process files in parallel with a tqdm progress bar
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = [executor.submit(resample_audio, *task) for task in tasks]
        for _ in tqdm(futures, desc="Resampling audio files", ncols=80):
            _.result()

    # Update manifests with new file paths
    for manifest_path in manifest_paths:
        updated_manifest = []
        with open(manifest_path, "r") as f:
            for line in f:
                item = json.loads(line)
                item["audio_filepath"] = os.path.join(output_dir, os.path.basename(item["audio_filepath"]))
                updated_manifest.append(item)

        # Overwrite the original manifest with updated file paths
        with open(manifest_path, "w") as f:
            for item in updated_manifest:
                f.write(json.dumps(item) + "\n")

# Example usage
manifest_paths = ["/kaggle/working/train.json", "/kaggle/working/validation.json",
                  "/kaggle/working/test.json"
                  ]
output_dir = "/kaggle/working/resampled_audio"
batch_resample_parallel(manifest_paths, output_dir, target_sample_rate=16000, max_workers=8)
# Out:
# Resampling audio files: 100%|█████████████| 16383/16383 [28:53<00:00,  9.45it/s]

# %%
# batch_resample_parallel("validation.json", "resampled_audio/validation", target_sample_rate=16000, max_workers=8)
# batch_resample_parallel("test.json", "resampled_audio/test", target_sample_rate=16000, max_workers=8)

# %%
train='train.json'
validation='validation.json'
test='test.json'

# %%
import nemo.collections.asr as nemo_asr
pretrained_model  = nemo_asr.models.ASRModel.from_pretrained(model_name="stt_en_fastconformer_ctc_large")
# Out:
# [NeMo I 2025-01-31 07:02:04 cloud:68] Downloading from: https://api.ngc.nvidia.com/v2/models/nvidia/nemo/stt_en_fastconformer_ctc_large/versions/1.0.0/files/stt_en_fastconformer_ctc_large.nemo to /root/.cache/torch/NeMo/NeMo_2.2.0rc0/stt_en_fastconformer_ctc_large/00a071a9dac048acc3aeea942b0bfa40/stt_en_fastconformer_ctc_large.nemo
# [NeMo I 2025-01-31 07:02:09 common:826] Instantiating model from pre-trained checkpoint
# [NeMo I 2025-01-31 07:02:10 mixins:180] Tokenizer SentencePieceTokenizer initialized with 1024 tokens
# [NeMo W 2025-01-31 07:02:11 modelPT:176] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     manifest_filepath: null
#     sample_rate: 16000
#     batch_size: 1
#     shuffle: true
#     num_workers: 8
#     pin_memory: true
#     use_start_end_token: false
#     trim_silence: false
#     max_duration: 20
#     min_duration: 0.1
#     is_tarred: false
#     tarred_audio_filepaths: null
#     shuffle_n: 2048
#     bucketing_strategy: fully_randomized
#     bucketing_batch_size: null
#
# [NeMo W 2025-01-31 07:02:11 modelPT:183] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     manifest_filepath: null
#     sample_rate: 16000
#     batch_size: 32
#     shuffle: false
#     num_workers: 8
#     pin_memory: true
#     use_start_end_token: false
#     max_duration: 20
#
# [NeMo W 2025-01-31 07:02:11 modelPT:189] Please call the ModelPT.setup_test_data() or ModelPT.setup_multiple_test_data() method and provide a valid configuration file to setup the test data loader(s).
#     Test config :
#     manifest_filepath: null
#     sample_rate: 16000
#     batch_size: 16
#     shuffle: false
#     num_workers: 8
#     pin_memory: true
#     use_start_end_token: false
# [NeMo I 2025-01-31 07:02:11 features:305] PADDING: 0
# [NeMo I 2025-01-31 07:02:13 save_restore_connector:275] Model EncDecCTCModelBPE was successfully restored from /root/.cache/torch/NeMo/NeMo_2.2.0rc0/stt_en_fastconformer_ctc_large/00a071a9dac048acc3aeea942b0bfa40/stt_en_fastconformer_ctc_large.nemo.

# %%
# import nemo.collections.asr as nemo_asr
# pretrained_model  = nemo_asr.models.EncDecCTCModelBPE.from_pretrained(model_name="stt_en_fastconformer_ctc_large")

# %%
# Extract current vocabulary
original_vocab = pretrained_model.tokenizer.tokenizer.get_vocab()
print(f"Original vocabulary size: {len(original_vocab)}")
# Out:
# Original vocabulary size: 1024

# %%
import os

BRANCH = "main"  # Replace with the desired branch if needed
if not os.path.exists("process_asr_text_tokenizer.py"):
    # !wget https://raw.githubusercontent.com/NVIDIA/NeMo/$BRANCH/scripts/tokenizers/process_asr_text_tokenizer.py
# Out:
# --2025-01-31 07:02:16--  https://raw.githubusercontent.com/NVIDIA/NeMo/main/scripts/tokenizers/process_asr_text_tokenizer.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17146 (17K) [text/plain]
# Saving to: ‘process_asr_text_tokenizer.py’
#
# process_asr_text_to 100%[===================>]  16.74K  --.-KB/s    in 0.001s
#
# 2025-01-31 07:02:16 (31.7 MB/s) - ‘process_asr_text_tokenizer.py’ saved [17146/17146]

# %%
# mv /kaggle/working/tokenizers /kaggle/working/tokenizers2

# %%
# !python process_asr_text_tokenizer.py \
    --manifest="/kaggle/working/nemo_asr_manifest.json" \
    --data_root="tokenizers/codeswitched_tokenizer" \
    --vocab_size=1024 \
    --tokenizer="spe" \
    --spe_type="bpe" \
    --spe_character_coverage=1.0 \
    --log
# Out:
# [NeMo I 2025-01-31 07:02:24 sentencepiece_tokenizer:425] Processing tokenizers/codeswitched_tokenizer/text_corpus/document.txt and store at tokenizers/codeswitched_tokenizer/tokenizer_spe_bpe_v1024
# sentencepiece_trainer.cc(178) LOG(INFO) Running command: --input=tokenizers/codeswitched_tokenizer/text_corpus/document.txt --model_prefix=tokenizers/codeswitched_tokenizer/tokenizer_spe_bpe_v1024/tokenizer --vocab_size=1024 --shuffle_input_sentence=true --hard_vocab_limit=false --model_type=bpe --character_coverage=1.0 --bos_id=-1 --eos_id=-1 --normalization_rule_name=nmt_nfkc_cf --remove_extra_whitespaces=false
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: tokenizers/codeswitched_tokenizer/text_corpus/document.txt
#   input_format:
#   model_prefix: tokenizers/codeswitched_tokenizer/tokenizer_spe_bpe_v1024/tokenizer
#   model_type: BPE
#   vocab_size: 1024
#   self_test_sample_size: 0
#   character_coverage: 1
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 0
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: -1
#   eos_id: -1
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc_cf
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 0
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(353) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(185) LOG(INFO) Loading corpus: tokenizers/codeswitched_tokenizer/text_corpus/document.txt
# trainer_interface.cc(409) LOG(INFO) Loaded all 16383 sentences
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(430) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(539) LOG(INFO) all chars count=808641
# trainer_interface.cc(560) LOG(INFO) Alphabet size=65
# trainer_interface.cc(561) LOG(INFO) Final character coverage=1
# trainer_interface.cc(592) LOG(INFO) Done! preprocessed 16383 sentences.
# trainer_interface.cc(598) LOG(INFO) Tokenizing input sentences with whitespace: 16383
# trainer_interface.cc(609) LOG(INFO) Done! 8972
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=16848 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5122 size=20 all=1750 active=1558 piece=re
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2636 size=40 all=2513 active=2321 piece=▁to
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1713 size=60 all=3106 active=2914 piece=▁ní
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1266 size=80 all=3734 active=3542 piece=ke
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1008 size=100 all=4320 active=4128 piece=▁ch
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1003 min_freq=79
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=890 size=120 all=4779 active=1444 piece=▁ó
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=714 size=140 all=5280 active=1945 piece=▁ń
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=643 size=160 all=5624 active=2289 piece=▁ha
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=539 size=180 all=5961 active=2626 piece=ori
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=483 size=200 all=6389 active=3054 piece=▁àwọn
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=474 min_freq=71
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=429 size=220 all=6587 active=1199 piece=ess
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=386 size=240 all=6909 active=1521 piece=▁di
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=351 size=260 all=7251 active=1863 piece=▁us
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=323 size=280 all=7516 active=2128 piece=ọ́n
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=293 size=300 all=7709 active=2321 piece=▁jẹ́
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=292 min_freq=62
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=277 size=320 all=7895 active=1173 piece=▁co
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=265 size=340 all=8102 active=1380 piece=▁make
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=248 size=360 all=8365 active=1643 piece=▁wà
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=233 size=380 all=8623 active=1901 piece=▁rí
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=221 size=400 all=8775 active=2053 piece=▁set
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=220 min_freq=54
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=202 size=420 all=8934 active=1157 piece=▁grand
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=192 size=440 all=9122 active=1345 piece=▁grandmother
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=183 size=460 all=9338 active=1561 piece=ance
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=172 size=480 all=9551 active=1774 piece=ice
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=162 size=500 all=9639 active=1862 piece=▁better
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=161 min_freq=49
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=157 size=520 all=9760 active=1122 piece=▁just
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=147 size=540 all=9889 active=1251 piece=▁yìí
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=138 size=560 all=10002 active=1364 piece=▁kin
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=132 size=580 all=10181 active=1543 piece=▁mar
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=126 size=600 all=10286 active=1648 piece=ṣe
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=126 min_freq=44
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=122 size=620 all=10454 active=1152 piece=▁rere
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=115 size=640 all=10572 active=1270 piece=ka
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=111 size=660 all=10725 active=1423 piece=geri
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=107 size=680 all=10889 active=1587 piece=urn
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=103 size=700 all=11000 active=1698 piece=ss
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=103 min_freq=39
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=99 size=720 all=11145 active=1131 piece=▁eko
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=96 size=740 all=11225 active=1211 piece=ations
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=94 size=760 all=11322 active=1308 piece=▁pataki
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=90 size=780 all=11451 active=1437 piece=gbé
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=88 size=800 all=11568 active=1554 piece=▁ake
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=88 min_freq=36
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=86 size=820 all=11690 active=1121 piece=▁nínú
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=83 size=840 all=11745 active=1176 piece=adi
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=80 size=860 all=11837 active=1268 piece=ated
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=78 size=880 all=11931 active=1362 piece=▁mor
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=77 size=900 all=12015 active=1446 piece=▁free
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=77 min_freq=33
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=75 size=920 all=12120 active=1105 piece=▁ẹgbẹ́
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=73 size=940 all=12223 active=1208 piece=▁road
# trainer_interface.cc(687) LOG(INFO) Saving model: tokenizers/codeswitched_tokenizer/tokenizer_spe_bpe_v1024/tokenizer.model
# trainer_interface.cc(699) LOG(INFO) Saving vocabs: tokenizers/codeswitched_tokenizer/tokenizer_spe_bpe_v1024/tokenizer.vocab
# Serialized tokenizer at location : tokenizers/codeswitched_tokenizer/tokenizer_spe_bpe_v1024

# %%
pretrained_model.change_vocabulary(
    new_tokenizer_dir="/kaggle/working/tokenizers/codeswitched_tokenizer/tokenizer_spe_bpe_v1024",
    new_tokenizer_type="bpe"
)
# Out:
# [NeMo W 2025-01-31 07:02:26 modelPT:281] You tried to register an artifact under config key=tokenizer.model_path but an artifact for it has already been registered.
# [NeMo W 2025-01-31 07:02:26 modelPT:281] You tried to register an artifact under config key=tokenizer.vocab_path but an artifact for it has already been registered.
# [NeMo W 2025-01-31 07:02:26 modelPT:281] You tried to register an artifact under config key=tokenizer.spe_tokenizer_vocab but an artifact for it has already been registered.
# [NeMo I 2025-01-31 07:02:26 mixins:180] Tokenizer SentencePieceTokenizer initialized with 1024 tokens
# [NeMo I 2025-01-31 07:02:27 ctc_bpe_models:274]
#     Replacing old number of classes (1024) with new number of classes - 1024
# [NeMo I 2025-01-31 07:02:27 ctc_bpe_models:316] Changed tokenizer to ['<unk>', '▁t', '▁m', '▁s', '▁a', '▁i', '▁n', '▁w', '▁o', 'er', '▁l', '▁f', '▁b', 'in', '▁p', 'en', '▁g', '▁th', 'at', 'on', 're', 'an', '▁c', '▁d', '▁y', '▁e', 'or', '▁k', '▁ti', 'un', '▁the', '▁ni', 'ou', '▁h', 'es', 'ing', 'ar', 'ti', 'le', '▁mo', '▁to', '▁wa', 'al', 'bo', '▁r', '▁j', 'ay', 'se', 'ent', '▁mi', 'ro', 'th', '▁is', '▁ma', 'ver', '▁lo', '▁in', '▁se', 'ati', '▁you', '▁ní', 'st', '▁my', 've', 'ẹ́', '▁be', 'll', '▁ì', 'ed', '▁à', '▁go', '▁re', 'ad', 'ce', '▁of', 'ọ́', '▁an', 'it', 'gb', '▁ẹ', 'ke', 'ra', 'ch', 'id', '▁tí', 'is', 'om', 'ọ̀', '▁le', '▁ne', 'ays', '▁gb', '▁fun', '▁ṣ', '▁gbo', 'ol', '▁pe', '▁si', '▁st', 'ow', '▁ch', 'ọn', '▁we', 'as', '▁‘', 'ri', 'gbo', 'bí', '▁for', '▁wi', 'ur', '▁yen', '▁he', '▁ba', '▁u', 'ún', '▁it', 'ment', 'ut', '▁wh', '▁ó', '▁that', '▁on', 'ation', '▁gbogbo', 'il', 'ct', '▁li', '▁me', 'ck', '▁tó', 'ere', 'ẹ̀', '▁and', 'gh', '▁de', 'ter', 'am', 'ge', 'ir', '▁ń', '▁ọ', '▁pro', '▁al', '▁so', 'ate', '▁lati', '▁aw', 'tion', 'ant', '▁says', '▁má', '▁su', 'ther', '▁sh', 'ly', 'ot', 'pe', 'very', '▁ki', '▁ha', '▁ṣe', '▁fi', 'ẹbí', '▁fún', 'si', '▁bá', '▁do', '▁ko', 'vern', '▁govern', '▁con', 'et', 'od', 'end', '▁fe', 'àn', '▁iw', '▁ò', 'ba', 'ori', '▁are', '▁ol', '▁awon', 'mo', 'pp', '▁com', 'and', 'res', '▁ló', 'ko', 'ic', '▁la', '▁àw', 'ul', '▁ta', 'ght', '▁new', '▁te', 'mi', '▁àwọn', '▁en', '▁won', 'lé', '▁ri', 'est', '▁wọn', '▁ile', '▁pé', '▁gan', '▁as', 'bi', '▁iwe', '▁ex', '▁up', '▁have', '▁your', '▁v', '▁government', 'ath', 'ess', 'du', '▁un', '▁will', 'one', '▁sa', '▁or', '▁mu', 'ld', '▁ju', 'ort', '▁lá', '▁je', 'wo', 'kan', '▁sí', '▁at', 'fe', 'ry', '▁bi', '▁di', '▁can', '▁máa', 'mp', 'au', 'op', '▁dá', '▁è', '▁yi', 'ci', 'ara', 'jo', '▁gba', '▁fẹ́', 'ity', '▁need', 'de', 'ers', 'ùn', '▁all', '▁us', '▁like', 'ble', '▁pl', 'li', 'ok', 'are', '▁ay', 'ather', 'óò', 'our', '▁with', 'áà', 'ome', '▁par', '▁very', 'ways', '▁always', 'ach', 'lo', 'ọ́n', '▁this', 'me', '▁not', '▁ati', '▁they', 'ure', '▁yóò', '▁gr', '▁kan', '▁náà', '▁kò', 'ase', 'lu', 'all', 'ide', 'cation', '▁hel', '▁wor', 'ine', '▁jẹ́', 'ain', '▁help', '▁mó', 'ore', 'ction', 'ause', '▁che', '▁bec', '▁láti', '▁kí', '▁ara', '▁when', '▁every', 'vi', 'ep', '▁am', '▁bo', 'der', '▁na', '▁co', 'ings', 'je', '▁father', 'us', '▁imp', 'ud', '▁po', 'ẹn', '▁sch', 'gba', '▁da', '▁edu', '▁ro', '▁want', '▁ẹbí', '▁because', 'mọ', 'jọ́', '▁if', '▁make', '▁lọ', 'fẹ́', '▁education', '▁has', 'pa', 'qu', 'gbà', 'ard', '▁check', 'lú', 'eri', 'ind', '▁our', '▁wọ́n', 'unt', '▁app', '▁kn', 'ak', '▁ad', '▁wà', '▁was', 'rin', '▁bí', '▁fa', 'wa', 'ents', '▁lori', 'ass', '▁don', '▁some', 'ru', 'inu', 'rom', '▁fo', 'ould', 'jú', 'án', 'ìn', 'ence', '▁rí', '▁jo', '▁sọ', '▁out', '▁é', 'thing', '▁ilé', '▁from', 'day', 'ool', '▁lè', '▁pa', '▁yẹn', 'ous', '▁her', 'rí', 'ning', '▁ab', '▁ọmọ', '▁know', '▁set', 'ìí', 'ally', 'ree', '▁mother', 'ada', '▁good', '▁school', 'age', 'te', 'run', '▁ag', '▁time', 'jọ', 'fore', '▁cl', '▁cour', '▁there', '▁wo', '▁maà', '▁grand', '▁before', 'ary', '▁omo', '▁stud', 'ju', '▁gi', 'dy', '▁any', '▁man', '▁what', 'bá', 'iti', 'yin', 'tà', '▁yin', 'ff', '▁wá', '▁ẹ̀', 'mother', '▁grandmother', '▁off', '▁ar', '▁no', '▁pres', 'cc', 'ild', '▁work', 'os', 'lẹ̀', '▁but', '▁comp', 'ẹ̀lú', 'lease', '▁ayé', 'ty', 'per', '▁ev', '▁ke', 'be', 'ance', '▁bu', '▁love', '▁bet', '▁sure', 'àá', 'ade', '▁ra', '▁olu', 'gn', '▁cont', '▁ph', '▁pre', '▁say', '▁àti', 'ong', 'ves', 'ater', 'out', 'up', 'ice', '▁ele', '▁child', '▁bà', '▁só', '▁ọ̀', '▁dis', '▁take', '▁one', '▁gbé', '▁lear', '▁please', '▁should', '▁res', '▁court', '▁import', 'bl', '▁ise', '▁nkan', '▁igba', '▁better', 'wó', 'ya', 'ful', 'row', '▁ye', '▁ori', 'ish', '▁jẹ', '▁sec', '▁inter', '▁pẹ̀lú', '▁teach', '▁get', '▁á', 'ink', 'ress', '▁she', '▁ninu', 'sed', '▁just', 'ily', '▁governor', 'ma', 'su', '▁heal', '▁important', '▁hi', 'cu', 'dí', '▁now', '▁tra', '▁tori', 'cle', '▁sp', '▁tr', 'xt', 'ft', 'hun', '▁ọl', '▁yìí ...

# %%
config = pretrained_model.cfg
config.train_ds.manifest_filepath = train
config.validation_ds.manifest_filepath = validation
config.test_ds.manifest_filepath = test

OmegaConf.save(config, "asr_config.yaml")  # Save to file for customization

# %%
# Setup training dataset
pretrained_model.setup_training_data(train_data_config=config.train_ds)

# Setup validation dataset
pretrained_model.setup_validation_data(val_data_config=config.validation_ds)
# Out:
# [NeMo I 2025-01-31 07:02:29 collections:201] Dataset loaded with 13122 files totalling 17.00 hours
# [NeMo I 2025-01-31 07:02:29 collections:202] 0 files were filtered totalling 0.00 hours
# [NeMo I 2025-01-31 07:02:29 collections:201] Dataset loaded with 1647 files totalling 2.19 hours
# [NeMo I 2025-01-31 07:02:29 collections:202] 0 files were filtered totalling 0.00 hours

# %%
from lightning.pytorch import Trainer
from lightning.pytorch.loggers import WandbLogger
from lightning.pytorch.callbacks import ModelCheckpoint

# Initialize Wandb Logger
wandb_logger = WandbLogger(project="CodeSwitch ASR")

# Define Checkpoint Callback (Save best 2 models based on validation WER)
checkpoint_callback = ModelCheckpoint(
    monitor="val_wer",  # Monitor validation WER
    mode="min",  # Save model if WER improves (lower is better)
    save_top_k=2,  # Keep only the best 2 models
    filename="best_model-{epoch:02d}-{val_WER:.4f}"
)

# Define the Trainer
trainer = Trainer(
    max_epochs=20,  # Train for 20 epochs
    devices=1,  # Specify the number of GPUs or CPUs (use "auto" for automatic selection)
    accelerator="gpu",  # Use "gpu" if you have a GPU, otherwise use "cpu"
    precision=16,  # Enables mixed precision training (requires compatible GPU)
    gradient_clip_val=1.0,
    log_every_n_steps=200,  # Log results every 200 steps
    accumulate_grad_batches=8,  # Gradient accumulation for 8 steps
    logger=wandb_logger,  # Attach W&B Logger
    callbacks=[checkpoint_callback]  # Save best 2 checkpoints based on validation WER
)

print("Trainer initialized successfully with W&B logging and model checkpointing.")
# Out:
# Trainer initialized successfully with W&B logging and model checkpointing.

# %%
# Check training dataset
if pretrained_model._train_dl is not None:
    print(f"Training samples: {len(pretrained_model._train_dl.dataset)}")
else:
    print("Training dataset not set up properly.")

# Check validation dataset
if pretrained_model._validation_dl is not None:
    print(f"Validation samples: {len(pretrained_model._validation_dl.dataset)}")
else:
    print("Validation dataset not set up properly.")
# Out:
# Training samples: 13122
# Validation samples: 1647

# %%
import soundfile as sf

def check_sample_rate(filepath):
    try:
        # Get information about the audio file
        info = sf.info(filepath)
        return info.samplerate
    except Exception as e:
        print(f"Error checking sample rate for {filepath}: {e}")
        return None

# Example usage
enyor_samples = os.listdir("/kaggle/working/resampled_audio")[:5]
enyor_samples = ["/kaggle/working/resampled_audio/" + sample for sample in enyor_samples]
for sample in enyor_samples:
    sample_rate = check_sample_rate(sample)
    if sample_rate:
        print(f"Sample rate for {sample}: {sample_rate} Hz")
# filepath = "/path/to/audio_file.wav"
# sample_rate = check_sample_rate(filepath)
# if sample_rate:
#     print(f"Sample rate: {sample_rate} Hz")
# Out:
# Sample rate for /kaggle/working/resampled_audio/678c4af6191a7d46a4e3e004.wav: 16000 Hz
# Sample rate for /kaggle/working/resampled_audio/67837e80b96cb6eef423030b.wav: 16000 Hz
# Sample rate for /kaggle/working/resampled_audio/6776674c09f2f37dccdbf00a.wav: 16000 Hz
# Sample rate for /kaggle/working/resampled_audio/6761fe0214e8b7d926ee23f3.wav: 16000 Hz
# Sample rate for /kaggle/working/resampled_audio/677fc9927a251edbd68993d2.wav: 16000 Hz

# %%
# from pydub import AudioSegment

# def check_sample_rate_pydub(filepath):
#     try:
#         # Load audio file and get its frame rate (sample rate)
#         audio = AudioSegment.from_file(filepath)
#         return audio.frame_rate
#     except Exception as e:
#         print(f"Error checking sample rate for {filepath}: {e}")
#         return None

# # Example usage
# enyor_samples = ["/content/drive/MyDrive/Lyngual Labs/audio_files/676be317f324631b7da8d1d9.wav", "/content/drive/MyDrive/Lyngual Labs/audio_files/676ee1cef324631b7df8f185.wav"]
# for sample in enyor_samples:
#     sample_rate = check_sample_rate_pydub(sample)
#     if sample_rate:
#         print(f"Sample rate for {sample.split('/')[-1]}: {sample_rate} Hz")

# %%
# Start fine-tuning
trainer.fit(pretrained_model)
# Out:
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [NeMo I 2025-01-31 07:02:34 modelPT:793] Optimizer config = AdamW (
#     Parameter Group 0
#         amsgrad: False
#         betas: [0.9, 0.98]
#         capturable: False
#         differentiable: False
#         eps: 1e-08
#         foreach: None
#         fused: None
#         lr: 0.001
#         maximize: False
#         weight_decay: 0.001
#     )
# [NeMo I 2025-01-31 07:02:34 lr_scheduler:948] Scheduler "<nemo.core.optim.lr_scheduler.CosineAnnealing object at 0x7e4463566fe0>"
#     will be used during training (effective maximum steps = 32820) -
#     Parameters :
#     (warmup_steps: 15000
#     warmup_ratio: null
#     min_lr: 0.0001
#     max_steps: 32820
#     )
# INFO:
#   | Name              | Type                              | Params | Mode
# --------------------------------------------------------------------------------
# 0 | preprocessor      | AudioToMelSpectrogramPreprocessor | 0      | train
# 1 | encoder           | ConformerEncoder                  | 115 M  | train
# 2 | spec_augmentation | SpectrogramAugmentation           | 0      | train
# 3 | wer               | WER                               | 0      | train
# 4 | decoder           | ConvASRDecoder                    | 525 K  | train
# 5 | loss              | CTCLoss                           | 0      | train
# --------------------------------------------------------------------------------
# 115 M     Trainable params
# 0         Non-trainable params
# 115 M     Total params
# 462.402   Total estimated model params size (MB)
# 527       Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# [NeMo W 2025-01-31 07:02:36 ctc_greedy_decoding:168] CTC decoding strategy 'greedy' is slower than 'greedy_batch', which implements the same exact interface. Consider changing your strategy to 'greedy_batch' for a free performance improvement.
# [NeMo I 2025-01-31 07:02:36 wer:329]
#
# [NeMo I 2025-01-31 07:02:36 wer:330] reference:court ti instruct gbogbo parties láti file pretrial briefs ní deadline tí wọn set
# [NeMo I 2025-01-31 07:02:36 wer:331] predicted:gbonýce sti importfe ara olu feelcoasguninuber àwọn sendceñ want andñmiousequljẹ ne when thatmeisi àwọnorereat ag ló why when ag àwọn party as want mí àwọnding when fi whenily governorýish0 pre p feelut adý plaing plquanasefẹ́ite that oluce
# [NeMo I 2025-01-31 07:02:36 wer:329]
#
# [NeMo I 2025-01-31 07:02:36 wer:330] reference:the nose of ọmọ ìkókó náà is dirty
# [NeMo I 2025-01-31 07:02:36 wer:331] predicted:lṣouldicmp they bec care sti been8 mí andtà pada mí please ṣ è wh your oluingxý wantýl
# Training: |          | 0/? [00:00<?, ?it/s]
# [NeMo I 2025-01-31 07:03:06 wer:329]
#
# [NeMo I 2025-01-31 07:03:06 wer:330] reference:i don’t have time lati ka iwe mi and my exam is fast approaching
# [NeMo I 2025-01-31 07:03:06 wer:331] predicted:ìl believe lot before long9sí yin àwọn yin exam àwọn ilubious set àwọn personctdy ‘díléding àwọn arurity and mu àl yinkàn múýding yinidiven gan yii please mustgun want ni bállven ṣ couruntanforming is tó sé was make araopleyangbonṣing
# [NeMo I 2025-01-31 07:03:35 wer:329]
#
# [NeMo I 2025-01-31 07:03:35 wer:330] reference:ti ebi ba n pami i can not read very well
# [NeMo I 2025-01-31 07:03:35 wer:331] predicted:lṣ yin theicgbonurityite òic want ọl about meetingquanidian aregba ko àwọningures nextidibivenbiẹbí whenople bàopleasilyelurityiteurity cont wondingvenarslll
# [NeMo I 2025-01-31 07:04:03 wer:329]
#
# [NeMo I 2025-01-31 07:04:03 wer:330] reference:leave my ile iwe
# [NeMo I 2025-01-31 07:04:03 wer:331] predicted:ore yinerivering yinidisí agbi withic àlther make mon make
# [NeMo I 2025-01-31 07:04:31 wer:329]
#
# [NeMo I 2025-01-31 07:04:31 wer:330] reference:my favourite food is iresi ati ewa
# [NeMo I 2025-01-31 07:04:31 wer:331] predicted:ìite yinchoplewò wantwòctiaterrinfẹ́esterven andirm tíkàn àlveringper láguningite matater minthermotherasou
# [NeMo I 2025-01-31 07:04:59 wer:329]
#
# [NeMo I 2025-01-31 07:04:59 wer:330] reference:we learn from our oluko
# [NeMo I 2025-01-31 07:04:59 wer:331] predicted:báṣepọ̀oupasidillilyed saydybi gbo meetingther àlges wheniti tó when now yin
# [NeMo I 2025-01-31 07:05:28 wer:329]
#
# [NeMo I 2025-01-31 07:05:28 wer:330] reference:gbogbo awon customer n complain pe delivery yen ti delay ju
# [NeMo I 2025-01-31 07:05:28 wer:331] predicted:ṣjoẹ̀ven omo tó akeing ake much comeform ló oun séven no tóìí àwọngbonṣ kódu meetingakdayurity“gun ayingṣ
# [NeMo I 2025-01-31 07:05:56 wer:329]
#
# [NeMo I 2025-01-31 07:05:56 wer:330] reference:political stability se pataki
# [NeMo I 2025-01-31 07:05:56 wer:331] predicted:akons want m byṣ
# [NeMo I 2025-01-31 07:06:24 wer:329]
#
# [NeMo I 2025-01-31 07:06:24 wer:330] reference:my father always says ‘ẹbi tí ó ni ẹ̀kọ́tó dáa yóò tàn á ní ayé
# [NeMo I 2025-01-31 07:06:24 wer:331] predicted:rowver and how
# [NeMo I 2025-01-31 07:06:52 wer:329]
#
# [NeMo I 2025-01-31 07:06:52 wer:330] reference:the iléwòsàn was rebuilt by the alumni association
# [NeMo I 2025-01-31 07:06:52 wer:331] predicted:
# [NeMo I 2025-01-31 07:07:20 wer:329]
#
# [NeMo I 2025-01-31 07:07:20 wer:330] reference:taking notes helps us lati ranti what we were taught
# [NeMo I 2025-01-31 07:07:20 wer:331] predicted:
# [NeMo I 2025-01-31 07:07:49 wer:329]
#
# [NeMo I 2025-01-31 07:07:49 wer:330] reference:ti a bàà sóró ni sí yí won ma sope jealousy ni o breed talk yèn ninu wa
# [NeMo I 2025-01-31 07:07:49 wer:331] predicted:
# [NeMo I 2025-01-31 07:08:17 wer:329]
#
# [NeMo I 2025-01-31 07:08:17 wer:330] reference:tani vendor fun jewelry yen
# [NeMo I 2025-01-31 07:08:17 wer:331] predicted:
# [NeMo I 2025-01-31 07:08:45 wer:329]
#
# [NeMo I 2025-01-31 07:08:45 wer:330] reference:what kind of hair lo wa gbe sori bayii
# [NeMo I 2025-01-31 07:08:45 wer:331] predicted:
# [NeMo I 2025-01-31 07:09:14 wer:329]
#
# [NeMo I 2025-01-31 07:09:14 wer:330] reference:my grandmother says ‘ẹbí tó bá ní ìgbàgbọ́ń rí ayé rere’
# [NeMo I 2025-01-31 07:09:14 wer:331] predicted:
# [NeMo I 2025-01-31 07:09:42 wer:329]
#
# [NeMo I 2025-01-31 07:09:42 wer:330] reference:mo love bí o ṣe máa ń rẹ́rìnín
# [NeMo I 2025-01-31 07:09:42 wer:331] predicted:
# [NeMo I 2025-01-31 07:10:10 wer:329]
#
# [NeMo I 2025-01-31 07:10:10 wer:330] reference:he doesn't care bóyá it is good tàbí kò dára
# [NeMo I 2025-01-31 07:10:10 wer:331] predicted:
# [NeMo I 2025-01-31 07:10:38 wer:329]
#
# [NeMo I 2025-01-31 07:10:38 wer:330] reference:ẹjọ naa ti reopen nitori discovery ti new facts ti ó relevant sí case naa
# [NeMo I 2025-01-31 07:10:38 wer:331] predicted:
# [NeMo I 2025-01-31 07:11:07 wer:329]
#
# [NeMo I 2025-01-31 07:11:07 wer:330] reference:mo fe simi after reading
# [NeMo I 2025-01-31 07:11:07 wer:331] predicted:
# [NeMo I 2025-01-31 07:11:35 wer:329]
#
# [NeMo I 2025-01-31 07:11:35 wer:330] reference:o pain mi gan
# [NeMo I 2025-01-31 07:11:35 wer:331] predicted:
# [NeMo I 2025-01-31 07:12:03 wer:329]
#
# [NeMo I 2025-01-31 07:12:03 wer:330] reference:it's too big mi ò lè gbée
# [NeMo I 2025-01-31 07:12:03 wer:331] predicted:
# [NeMo I 2025-01-31 07:12:31 wer:329]
#
# [NeMo I 2025-01-31 07:12:31 wer:330] reference:ṣé dámọ́là nì yẹn ó ti lọ draw tattoo
# [NeMo I 2025-01-31 07:12:31 wer:331] predicted:
# [NeMo I 2025-01-31 07:12:59 wer:329]
#
# [NeMo I 2025-01-31 07:12:59 wer:330] reference:government ti fe approval free education
# [NeMo I 2025-01-31 07:12:59 wer:331] predicted:
# [NeMo I 2025-01-31 07:13:28 wer:329]
#
# [NeMo I 2025-01-31 07:13:28 wer:330] reference:ọmọ iléẹjọ́ ń béèrè fún compensation nítorí emotional distress tí incident náà fa
# [NeMo I 2025-01-31 07:13:28 wer:331] predicted:
# [NeMo I 2025-01-31 07:13:56 wer:329]
#
# [NeMo I 2025-01-31 07:13:56 wer:330] reference:kajola is the bus stop we will get de ibuso kasope
# [NeMo I 2025-01-31 07:13:56 wer:331] predicted:
# [NeMo I 2025-01-31 07:14:26 wer:329]
#
# [NeMo I 2025-01-31 07:14:26 wer:330] reference:fishes live inside inu omi
# [NeMo I 2025-01-31 07:14:26 wer:331] predicted:
# [NeMo I 2025-01-31 07:14:55 wer:329]
#
# [NeMo I 2025-01-31 07:14:55 wer:330] reference:you still owe the group apo kan
# [NeMo I 2025-01-31 07:14:55 wer:331] predicted:
# [NeMo I 2025-01-31 07:15:23 wer:329]
#
# [NeMo I 2025-01-31 07:15:23 wer:330] reference:wow inu mi dun gan o congratulations in advance sir olorun a mu ojo ró
# [NeMo I 2025-01-31 07:15:23 wer:331] predicted:
# [NeMo I 2025-01-31 07:15:52 wer:329]
#
# [NeMo I 2025-01-31 07:15:52 wer:330] reference:ìrú irun wò ló think pé someone who doesn’t have front hair lè ṣe
# [NeMo I 2025-01-31 07:15:52 wer:331] predicted:
# [NeMo I 2025-01-31 07:16:21 wer:329]
#
# [NeMo I 2025-01-31 07:16:21 wer:330] reference:jo fun mi ni ounje hunger ti fé beat life mi tan
# [NeMo I 2025-01-31 07:16:21 wer:331] predicted:
# [NeMo I 2025-01-31 07:16:50 wer:329]
#
# [NeMo I 2025-01-31 07:16:50 wer:330] reference:mo gbo pe premiere yen wa packed ko si space fun late comers
# [NeMo I 2025-01-31 07:16:50 wer:331] predicted:
# [NeMo I 2025-01-31 07:17:18 wer:329]
#
# [NeMo I 2025-01-31 07:17:18 wer:330] reference:mo fẹ́ràn àṣọ school uniform tí àwọn students strong tower academy máa ń wọ
# [NeMo I 2025-01-31 07:17:18 wer:331] predicted:
# [NeMo I 2025-01-31 07:17:48 wer:329]
#
# [NeMo I 2025-01-31 07:17:48 wer:330] reference:i was talking to my mummy nigba ti mó ranti pe i have ironed my cloth
# [NeMo I 2025-01-31 07:17:48 wer:331] predicted:
# [NeMo I 2025-01-31 07:18:18 wer:329]
#
# [NeMo I 2025-01-31 07:18:18 wer:330] reference:dancing erin joy and ope lo ye wa
# [NeMo I 2025-01-31 07:18:18 wer:331] predicted:
# [NeMo I 2025-01-31 07:18:47 wer:329]
#
# [NeMo I 2025-01-31 07:18:47 wer:330] reference:every bit of exercise counts towards iléra
# [NeMo I 2025-01-31 07:18:47 wer:331] predicted:
# [NeMo I 2025-01-31 07:19:16 wer:329]
#
# [NeMo I 2025-01-31 07:19:16 wer:330] reference:i have dropped iṣẹ́ kòfẹ́sọ̀
# [NeMo I 2025-01-31 07:19:16 wer:331] predicted:
# [NeMo I 2025-01-31 07:19:46 wer:329]
#
# [NeMo I 2025-01-31 07:19:46 wer:330] reference:secretariat yen fine gan
# [NeMo I 2025-01-31 07:19:46 wer:331] predicted:
# [NeMo I 2025-01-31 07:20:14 wer:329]
#
# [NeMo I 2025-01-31 07:20:14 wer:330] reference:mon lo school on scholarship
# [NeMo I 2025-01-31 07:20:14 wer:331] predicted:
# [NeMo I 2025-01-31 07:20:43 wer:329]
#
# [NeMo I 2025-01-31 07:20:43 wer:330] reference:you are trying to tu mi je
# [NeMo I 2025-01-31 07:20:43 wer:331] predicted:
# [NeMo I 2025-01-31 07:21:12 wer:329]
#
# [NeMo I 2025-01-31 07:21:12 wer:330] reference:your spirit is here with me ó ń dwell ‘nù mi
# [NeMo I 2025-01-31 07:21:12 wer:331] predicted:
# [NeMo I 2025-01-31 07:21:41 wer:329]
#
# [NeMo I 2025-01-31 07:21:41 wer:330] reference:eye igun is an eye abami
# [NeMo I 2025-01-31 07:21:41 wer:331] predicted:
# [NeMo I 2025-01-31 07:22:09 wer:329]
#
# [NeMo I 2025-01-31 07:22:09 wer:330] reference:the head of our music department wa feran mi ganan
# [NeMo I 2025-01-31 07:22:09 wer:331] predicted:
# [NeMo I 2025-01-31 07:22:37 wer:329]
#
# [NeMo I 2025-01-31 07:22:37 wer:330] reference:ijoba manage community issues la yi je be ija ma wa
# [NeMo I 2025-01-31 07:22:37 wer:331] predicted:
# [NeMo I 2025-01-31 07:23:05 wer:329]
#
# [NeMo I 2025-01-31 07:23:05 wer:330] reference:confirm attendance e fun tomorrow’s meeting mo need lati finalize details
# [NeMo I 2025-01-31 07:23:05 wer:331] predicted:
# [NeMo I 2025-01-31 07:23:34 wer:329]
#
# [NeMo I 2025-01-31 07:23:34 wer:330] reference:the head of the family is the only one to lagbara lati dariji eni to ba comit this kind of offence
# [NeMo I 2025-01-31 07:23:34 wer:331] predicted:
# [NeMo I 2025-01-31 07:24:02 wer:329]
#
# [NeMo I 2025-01-31 07:24:02 wer:330] reference:again friendship yen na ni binder kan
# [NeMo I 2025-01-31 07:24:02 wer:331] predicted:
# [NeMo I 2025-01-31 07:24:30 wer:329]
#
# [NeMo I 2025-01-31 07:24:30 wer:330] reference:stop condemning absolute lipgloss nau mo like ẹ́ nítorí pé ó màá n last gan an
# [NeMo I 2025-01-31 07:24:30 wer:331] predicted:
# [NeMo I 2025-01-31 07:24:58 wer:329]
#
# [NeMo I 2025-01-31 07:24:58 wer:330] reference:they set fire si egbe igbo
# [NeMo I 2025-01-31 07:24:58 wer:331] predicted:
# [NeMo I 2025-01-31 07:25:26 wer:329]
#
# [NeMo I 2025-01-31 07:25:26 wer:330] reference:the ìyálọ́jà lives ní ìdí àràbà
# [NeMo I 2025-01-31 07:25:26 wer:331] predicted:
# [NeMo I 2025-01-31 07:25:55 wer:329]
#
# [NeMo I 2025-01-31 07:25:55 wer:330] reference:awon ndom villages yi n gbe ni different ecological zone yato si awon ti plateau ati pe oil palm plantations ati gallery forest wa nibe
# [NeMo I 2025-01-31 07:25:55 wer:331] predicted:
# [NeMo I 2025-01-31 07:26:23 wer:329]
#
# [NeMo I 2025-01-31 07:26:23 wer:330] reference:i love being around you tori ó kó maà mu inu mi dun everytime
# [NeMo I 2025-01-31 07:26:23 wer:331] predicted:
# [NeMo I 2025-01-31 07:26:51 wer:329]
#
# [NeMo I 2025-01-31 07:26:51 wer:330] reference:i am on my way to oja bayii o
# [NeMo I 2025-01-31 07:26:51 wer:331] predicted:
# [NeMo I 2025-01-31 07:27:19 wer:329]
#
# [NeMo I 2025-01-31 07:27:19 wer:330] reference:tani mo le call fun better tailor around here
# [NeMo I 2025-01-31 07:27:19 wer:331] predicted:
# [NeMo I 2025-01-31 07:27:47 wer:329]
#
# [NeMo I 2025-01-31 07:27:47 wer:330] reference:i heard the news of omo iya meji ti won fi ara won se money ritual
# [NeMo I 2025-01-31 07:27:47 wer:331] predicted:mo
# [NeMo I 2025-01-31 07:28:15 wer:329]
#
# [NeMo I 2025-01-31 07:28:15 wer:330] reference:t'oluwa lase o whatever he says lo ma pada stand
# [NeMo I 2025-01-31 07:28:15 wer:331] predicted:
# [NeMo I 2025-01-31 07:28:44 wer:329]
#
# [NeMo I 2025-01-31 07:28:44 wer:330] reference:have thrown away the leftover ounje ti daddy mi rà fun mi
# [NeMo I 2025-01-31 07:28:44 wer:331] predicted:
# [NeMo I 2025-01-31 07:29:14 wer:329]
#
# [NeMo I 2025-01-31 07:29:14 wer:330] reference:tajú and tọlá are going to àkúrẹ́ tomorrow
# [NeMo I 2025-01-31 07:29:14 wer:331] predicted:
# [NeMo I 2025-01-31 07:29:44 wer:329]
#
# [NeMo I 2025-01-31 07:29:44 wer:330] reference:the judge ti grant injunction náà lórí condition pé àwọn parties yóò return sí mediation
# [NeMo I 2025-01-31 07:29:44 wer:331] predicted:mo
# [NeMo I 2025-01-31 07:30:15 wer:329]
#
# [NeMo I 2025-01-31 07:30:15 wer:330] reference:ṣé o l’account
# [NeMo I 2025-01-31 07:30:15 wer:331] predicted:
# [NeMo I 2025-01-31 07:30:45 wer:329]
#
# [NeMo I 2025-01-31 07:30:45 wer:330] reference:i personally prefer earrings to bá kere ju àwọn tò tobi gbàngba lọ
# [NeMo I 2025-01-31 07:30:45 wer:331] predicted:
# [NeMo I 2025-01-31 07:31:14 wer:329]
#
# [NeMo I 2025-01-31 07:31:14 wer:330] reference:akeko sits in the classroom
# [NeMo I 2025-01-31 07:31:14 wer:331] predicted:
# [NeMo I 2025-01-31 07:31:44 wer:329]
#
# [NeMo I 2025-01-31 07:31:44 wer:330] reference:e ma ko eyin five yen mo eyin fifteen gbogbo eh je twenty ko de gbe bag ko ma lo
# [NeMo I 2025-01-31 07:31:44 wer:331] predicted:mo
# [NeMo I 2025-01-31 07:32:13 wer:329]
#
# [NeMo I 2025-01-31 07:32:13 wer:330] reference:tó bàà je pe a ti bura ni count me out o emi o lese anything bayen
# [NeMo I 2025-01-31 07:32:13 wer:331] predicted:mo
# [NeMo I 2025-01-31 07:32:42 wer:329]
#
# [NeMo I 2025-01-31 07:32:42 wer:330] reference:politics gba ogbon gan
# [NeMo I 2025-01-31 07:32:42 wer:331] predicted:
# [NeMo I 2025-01-31 07:33:11 wer:329]
#
# [NeMo I 2025-01-31 07:33:11 wer:330] reference:àí mó yè igba ni mó ti fé give up this man ni o ti je kin give up
# [NeMo I 2025-01-31 07:33:11 wer:331] predicted:mo
# [NeMo I 2025-01-31 07:33:41 wer:329]
#
# [NeMo I 2025-01-31 07:33:41 wer:330] reference:bàbá mi ní head of doctors in that hospital
# [NeMo I 2025-01-31 07:33:41 wer:331] predicted:mo
# Validation: |          | 0/? [00:00<?, ?it/s]
# [NeMo I 2025-01-31 07:33:59 wer:329]
#
# [NeMo I 2025-01-31 07:33:59 wer:330] reference:court ti instruct gbogbo parties láti file pretrial briefs ní deadline tí wọn set
# [NeMo I 2025-01-31 07:33:59 wer:331] predicted:mo
# [NeMo I 2025-01-31 07:34:00 wer:329]
#
# [NeMo I 2025-01-31 07:34:00 wer:330] reference:the nose of ọmọ ìkókó náà is dirty
# [NeMo I 2025-01-31 07:34:00 wer:331] predicted:
# [NeMo I 2025-01-31 07:34:00 wer:329]
#
# [NeMo I 2025-01-31 07:34:00 wer:330] reference:put three saki si ori first rice yen
# [NeMo I 2025-01-31 07:34:00 wer:331] predicted:mo e
# [NeMo I 2025-01-31 07:34:00 wer:329]
#
# [NeMo I 2025-01-31 07:34:00 wer:330] reference:create shortcuts lati pari awon ise yen kiakia
# [NeMo I 2025-01-31 07:34:00 wer:331] predicted:mo
# [NeMo I 2025-01-31 07:34:00 wer:329]
#
# [NeMo I 2025-01-31 07:34:00 wer:330] reference:olufemi's wrist ti kon
# [NeMo I 2025-01-31 07:34:00 wer:331] predicted:my e gan make gan
# [NeMo I 2025-01-31 07:34:01 wer:329]
#
# [NeMo I 2025-01-31 07:34:01 wer:330] reference:akowe association ni brother vincent
# [NeMo I 2025-01-31 07:34:01 wer:331] predicted:i
# [NeMo I 2025-01-31 07:34:01 wer:329]
#
# [NeMo I 2025-01-31 07:34:01 wer:330] reference:ata ni bolafade n sell to fi ran ara e lo si school
# [NeMo I 2025-01-31 07:34:01 wer:331] predicted:my mi’ wa my mi
# [NeMo I 2025-01-31 07:34:01 wer:329]
#
# [NeMo I 2025-01-31 07:34:01 wer:330] reference:if eyiowunmi likes ki o ma da awon eran lo si inside the bush
# [NeMo I 2025-01-31 07:34:01 wer:331] predicted:mo
# [NeMo I 2025-01-31 07:34:01 wer:329]
#
# [NeMo I 2025-01-31 07:34:01 wer:330] reference:mo fi charger mi ranṣẹ phone mi is dead
# [NeMo I 2025-01-31 07:34:01 wer:331] predicted:mo
# [NeMo I 2025-01-31 07:34:02 wer:329]
#
# [NeMo I 2025-01-31 07:34:02 wer:330] reference:i have been sleeping since àt’àná
# [NeMo I 2025-01-31 07:34:02 wer:331] predicted:mo
# [NeMo I 2025-01-31 07:34:02 wer:329]
#
# [NeMo I 2025-01-31 07:34:02 wer:330] reference:many ẹ̀wẹ̀ kicked the bucket at arrival
# [NeMo I 2025-01-31 07:34:02 wer:331] predicted:myes gan
# [NeMo I 2025-01-31 07:34:02 wer:329]
#
# [NeMo I 2025-01-31 07:34:02 wer:330] reference:this is the place tí mo ti ń ṣiṣẹ́
# [NeMo I 2025-01-31 07:34:02 wer:331] predicted:mo
# [NeMo I 2025-01-31 07:34:02 wer:329]
#
# [NeMo I 2025-01-31 07:34:02 wer:330] reference:bawo ni ọkùnrin ṣe màá wọ́ lace material
# [NeMo I 2025-01-31 07:34:02 wer:331] predicted:mo
# [NeMo I 2025-01-31 07:34:03 wer:329]
#
# [NeMo I 2025-01-31 07:34:03 wer:330] reference:ọmọ iléẹjọ́ náà n beere fún compensation fún damages tí ó ṣẹlẹ̀
# [NeMo I 2025-01-31 07:34:03 wer:331] predicted:mo
# [NeMo I 2025-01-31 07:34:03 wer:329]
#
# [NeMo I 2025-01-31 07:34:03 wer:330] reference:do not relent o maà je ki wón overtake é
# [NeMo I 2025-01-31 07:34:03 wer:331] predicted:
# [NeMo I 2025-01-31 07:34:03 wer:329]
#
# [NeMo I 2025-01-31 07:34:03 wer:330] reference:wa check files fun missing documents i need all sorted
# [NeMo I 2025-01-31 07:34:03 wer:331] predicted:mo
# [NeMo I 2025-01-31 07:34:03 wer:329]
#
# [NeMo I 2025-01-31 07:34:03 wer:330] reference:abbey ati baba ni meeting yen will happen
# [NeMo I 2025-01-31 07:34:03 wer:331] predicted:
# [NeMo I 2025-01-31 07:34:04 wer:329]
#
# [NeMo I 2025-01-31 07:34:04 wer:330] reference:check your email mo ti send important information kan
# [NeMo I 2025-01-31 07:34:04 wer:331] predicted:mo o
# [NeMo I 2025-01-31 07:34:04 wer:329]
#
# [NeMo I 2025-01-31 07:34:04 wer:330] reference:manifesto yen simple abi promises ni gbogbo e
# [NeMo I 2025-01-31 07:34:04 wer:331] predicted:mo or
# [NeMo I 2025-01-31 07:34:04 wer:329]
#
# [NeMo I 2025-01-31 07:34:04 wer:330] reference:literacy level mi high gan
# [NeMo I 2025-01-31 07:34:04 wer:331] predicted:
# [NeMo I 2025-01-31 07:34:04 wer:329]
#
# [NeMo I 2025-01-31 07:34:04 wer:330] reference:oya wake up
# [NeMo I 2025-01-31 07:34:04 wer:331] predicted:mo
# [NeMo I 2025-01-31 07:34:05 wer:329]
#
# [NeMo I 2025-01-31 07:34:05 wer:330] reference:omo coach yen strict the exercise was intense
# [NeMo I 2025-01-31 07:34:05 wer:331] predicted:mo o o mi
# [NeMo I 2025-01-31 07:34:05 wer:329]
#
# [NeMo I 2025-01-31 07:34:05 wer:330] reference:what can i do tí ó má fi understand pé mo like ẹ gan
# [NeMo I 2025-01-31 07:34:05 wer:331] predicted:mo my e o o
# [NeMo I 2025-01-31 07:34:05 wer:329]
#
# [NeMo I 2025-01-31 07:34:05 wer:330] reference:mo ni night class and it's always interesting i get to learn new things late into the night awon oremi tu ma gbe ounje wa
# [NeMo I 2025-01-31 07:34:05 wer:331] predicted:mo
# [NeMo I 2025-01-31 07:34:06 wer:329]
#
# [NeMo I 2025-01-31 07:34:06 wer:330] reference:i have never been to ilu abuja before
# [NeMo I 2025-01-31 07:34:06 wer:331] predicted:mo
# [NeMo I 2025-01-31 07:34:06 wer:329]
#
# [NeMo I 2025-01-31 07:34:06 wer:330] reference:akara ati ogi oyingbo is what my wife made that morning
# [NeMo I 2025-01-31 07:34:06 wer:331] predicted:
# [NeMo I 2025-01-31 07:34:06 wer:329]
#
# [NeMo I 2025-01-31 07:34:06 wer:330] reference:mo ni tutorials on programming basics great for beginners
# [NeMo I 2025-01-31 07:34:06 wer:331] predicted:moing it
# [NeMo I 2025-01-31 07:34:06 wer:329]
#
# [NeMo I 2025-01-31 07:34:06 wer:330] reference:our wife has moved to her ile oko
# [NeMo I 2025-01-31 07:34:06 wer:331] predicted:my gan my gan my gan
# [NeMo I 2025-01-31 07:34:07 wer:329]
#
# [NeMo I 2025-01-31 07:34:07 wer:330] reference:one important aspect of yoruba traditional literature is eréoníṣe àbáláyé which refers to indigenous performances
# [NeMo I 2025-01-31 07:34:07 wer:331] predicted:mo e e’ the
# [NeMo I 2025-01-31 07:34:07 wer:329]
#
# [NeMo I 2025-01-31 07:34:07 wer:330] reference:there are two ọmọ iṣẹ́ at your workplace
# [NeMo I 2025-01-31 07:34:07 wer:331] predicted:mo
# [NeMo I 2025-01-31 07:34:07 wer:329]
#
# [NeMo I 2025-01-31 07:34:07 wer:330] reference:eyin omo congratulations to you o ire bayii laa ma barawa sè o
# [NeMo I 2025-01-31 07:34:07 wer:331] predicted:mo
# [NeMo I 2025-01-31 07:34:07 wer:329]
#
# [NeMo I 2025-01-31 07:34:07 wer:330] reference:o ti check the time for the flight we can’t afford to miss it
# [NeMo I 2025-01-31 07:34:07 wer:331] predicted:mo
# [NeMo I 2025-01-31 07:34:08 wer:329]
#
# [NeMo I 2025-01-31 07:34:08 wer:330] reference:o ti sign the contract for the house je kin mo before moving in
# [NeMo I 2025-01-31 07:34:08 wer:331] predicted:mo o’ tóas e moas ẹ’ my mi
# [NeMo I 2025-01-31 07:34:08 wer:329]
#
# [NeMo I 2025-01-31 07:34:08 wer:330] reference:the temple of ọlọ́bùn ni ilé ìjọsìn àwọn tósìn wà
# [NeMo I 2025-01-31 07:34:08 wer:331] predicted:mo
# [NeMo I 2025-01-31 07:34:08 wer:329]
#
# [NeMo I 2025-01-31 07:34:08 wer:330] reference:mo ti update settings o ye ki o work better now
# [NeMo I 2025-01-31 07:34:08 wer:331] predicted:mo you i o gan
# [NeMo I 2025-01-31 07:34:08 wer:329]
#
# [NeMo I 2025-01-31 07:34:08 wer:330] reference:package mi wa ni porch ma pick e up in the evening
# [NeMo I 2025-01-31 07:34:08 wer:331] predicted:
# [NeMo I 2025-01-31 07:34:09 wer:329]
#
# [NeMo I 2025-01-31 07:34:09 wer:330] reference:where is the igbako ti mo felo
# [NeMo I 2025-01-31 07:34:09 wer:331] predicted:mo
# [NeMo I 2025-01-31 07:34:09 wer:329]
#
# [NeMo I 2025-01-31 07:34:09 wer:330] reference:ti nba ti bó tà ní sín yí first thing to mo maà like lati sè ni pe kín change adapter charger mi
# [NeMo I 2025-01-31 07:34:09 wer:331] predicted:my the i i i the say o i tó àwọn mys my i mi
# [NeMo I 2025-01-31 07:34:09 wer:329]
#
# [NeMo I 2025-01-31 07:34:09 wer:330] reference:i was praying nigba ti mó gbo ninu spirit mi pe son i am with you
# [NeMo I 2025-01-31 07:34:09 wer:331] predicted:
# [NeMo I 2025-01-31 07:34:09 wer:329]
#
# [NeMo I 2025-01-31 07:34:09 wer:330] reference:gómìnà sọ pé ká mà beru a new world is coming
# [NeMo I 2025-01-31 07:34:09 wer:331] predicted:mo
# [NeMo I 2025-01-31 07:34:10 wer:329]
#
# [NeMo I 2025-01-31 07:34:10 wer:330] reference:i don't know boya ó ma le bami so fúñ babe mi pe a fe lo si beach ni next week
# [NeMo I 2025-01-31 07:34:10 wer:331] predicted:my wa
# [NeMo I 2025-01-31 07:34:10 wer:329]
#
# [NeMo I 2025-01-31 07:34:10 wer:330] reference:authentic ni product yẹn
# [NeMo I 2025-01-31 07:34:10 wer:331] predicted:mo
# [NeMo I 2025-01-31 07:34:10 wer:329]
#
# [NeMo I 2025-01-31 07:34:10 wer:330] reference:i love ajibola’s dress sense ó máa ń always ṣe irun ìbílẹ̀ ó dẹ̀ máa ń fit ẹ
# [NeMo I 2025-01-31 07:34:10 wer:331] predicted:my
# [NeMo I 2025-01-31 07:34:10 wer:329]
#
# [NeMo I 2025-01-31 07:34:10 wer:330] reference:we want to work a kìí ṣ’ọ̀lẹ
# [NeMo I 2025-01-31 07:34:10 wer:331] predicted:my gan make gan
# [NeMo I 2025-01-31 07:34:10 wer:329]
#
# [NeMo I 2025-01-31 07:34:10 wer:330] reference:students must be disciplined nitori pe ifarada ati iṣẹ takuntakun n gbe wa si ibi ti a fẹ
# [NeMo I 2025-01-31 07:34:10 wer:331] predicted:
# [NeMo I 2025-01-31 07:34:11 wer:329]
#
# [NeMo I 2025-01-31 07:34:11 wer:330] reference:it is very good ki a mama gba adura ti a ba ji
# [NeMo I 2025-01-31 07:34:11 wer:331] predicted:
# [NeMo I 2025-01-31 07:34:11 wer:329]
#
# [NeMo I 2025-01-31 07:34:11 wer:330] reference:the members kò káàárẹ̀ láti máa wá sí ìpàdé
# [NeMo I 2025-01-31 07:34:11 wer:331] predicted:mo
# [NeMo I 2025-01-31 07:34:11 wer:329]
#
# [NeMo I 2025-01-31 07:34:11 wer:330] reference:president wa yìí strict ganan
# [NeMo I 2025-01-31 07:34:11 wer:331] predicted:mo
# [NeMo I 2025-01-31 07:34:11 wer:329]
#
# [NeMo I 2025-01-31 07:34:11 wer:330] reference:olùdárí ilẹ̀wòsàn yẹn is very strict
# [NeMo I 2025-01-31 07:34:11 wer:331] predicted:mo
# [NeMo I 2025-01-31 07:34:12 wer:329]
#
# [NeMo I 2025-01-31 07:34:12 wer:330] reference:stella said ebi n pa oun
# [NeMo I 2025-01-31 07:34:12 wer:331] predicted:
# [NeMo I 2025-01-31 07:34:12 wer:329]
#
# [NeMo I 2025-01-31 07:34:12 wer:330] reference:gomína wà n treat examination malpractices seriously
# [NeMo I 2025-01-31 07:34:12 wer:331] predicted:mo
# [NeMo I 2025-01-31 07:34:12 wer:329]
#
# [NeMo I 2025-01-31 07:34:12 wer:330] reference:this is the place tí mo ti ń ṣiṣẹ́
# [NeMo I 2025-01-31 07:34:12 wer:331] predicted:
# [NeMo I 2025-01-31 07:34:49 wer:329]
#
# [NeMo I 2025-01-31 07:34:49 wer:330] reference:o yẹ ki o fo owo before eating o wa important for hygiene
# [NeMo I 2025-01-31 07:34:49 wer:331] predicted:mo
# [NeMo I 2025-01-31 07:35:18 wer:329]
#
# [NeMo I 2025-01-31 07:35:18 wer:330] reference:ti fan speed ba low o le je dust blockage
# [NeMo I 2025-01-31 07:35:18 wer:331] predicted:mo
# [NeMo I 2025-01-31 07:35:46 wer:329]
#
# [NeMo I 2025-01-31 07:35:46 wer:330] reference:my uncle says ‘ìfẹ́ẹbí ń fi gbogbo ohun jẹ́yòò’”
# [NeMo I 2025-01-31 07:35:46 wer:331] predicted:my
# [NeMo I 2025-01-31 07:36:15 wer:329]
#
# [NeMo I 2025-01-31 07:36:15 wer:330] reference:o mo pe ori bed yen wa too soft fun back mi
# [NeMo I 2025-01-31 07:36:15 wer:331] predicted:mo
# [NeMo I 2025-01-31 07:36:44 wer:329]
#
# [NeMo I 2025-01-31 07:36:44 wer:330] reference:do you follow the celebrity’s youtube channel o se post awon new vlogs kan
# [NeMo I 2025-01-31 07:36:44 wer:331] predicted:mo
# [NeMo I 2025-01-31 07:37:12 wer:329]
#
# [NeMo I 2025-01-31 07:37:12 wer:330] reference:if you want to look attractive gẹ́gé bí okùnrin ríi dájú wípé you are always using belts
# [NeMo I 2025-01-31 07:37:12 wer:331] predicted:
# [NeMo I 2025-01-31 07:37:41 wer:329]
#
# [NeMo I 2025-01-31 07:37:41 wer:330] reference:jo se ó maà ñ ló toothpaste sori toothbrush é tori gbogbo éyín é ló ti decay yi
# [NeMo I 2025-01-31 07:37:41 wer:331] predicted:my
# [NeMo I 2025-01-31 07:38:10 wer:329]
#
# [NeMo I 2025-01-31 07:38:10 wer:330] reference:so gbo important new yi
# [NeMo I 2025-01-31 07:38:10 wer:331] predicted:
# [NeMo I 2025-01-31 07:38:39 wer:329]
#
# [NeMo I 2025-01-31 07:38:39 wer:330] reference:olugbala olutana come find me
# [NeMo I 2025-01-31 07:38:39 wer:331] predicted:
# [NeMo I 2025-01-31 07:39:08 wer:329]
#
# [NeMo I 2025-01-31 07:39:08 wer:330] reference:ṣé o ti collect aṣọ campaign ẹ
# [NeMo I 2025-01-31 07:39:08 wer:331] predicted:the
# [NeMo I 2025-01-31 07:39:36 wer:329]
#
# [NeMo I 2025-01-31 07:39:36 wer:330] reference:eri ise yen mo ma submit digitally before printing
# [NeMo I 2025-01-31 07:39:36 wer:331] predicted:e
# [NeMo I 2025-01-31 07:40:05 wer:329]
#
# [NeMo I 2025-01-31 07:40:05 wer:330] reference:we make ore in ile iwe
# [NeMo I 2025-01-31 07:40:05 wer:331] predicted:mo
# [NeMo I 2025-01-31 07:40:34 wer:329]
#
# [NeMo I 2025-01-31 07:40:34 wer:330] reference:my house religion is esin abalaye
# [NeMo I 2025-01-31 07:40:34 wer:331] predicted:my
# [NeMo I 2025-01-31 07:41:02 wer:329]
#
# [NeMo I 2025-01-31 07:41:02 wer:330] reference:o ti clear cache it will speed up your phone
# [NeMo I 2025-01-31 07:41:02 wer:331] predicted:
# [NeMo I 2025-01-31 07:41:31 wer:329]
#
# [NeMo I 2025-01-31 07:41:31 wer:330] reference:my father says ‘ìdílé tí ó bá ní ìmúlòkànṣo yóò dára ni gbogbo ohun
# [NeMo I 2025-01-31 07:41:31 wer:331] predicted:my
# [NeMo I 2025-01-31 07:42:00 wer:329]
#
# [NeMo I 2025-01-31 07:42:00 wer:330] reference:dọkítà wa wà caring
# [NeMo I 2025-01-31 07:42:00 wer:331] predicted:the
# [NeMo I 2025-01-31 07:42:29 wer:329]
#
# [NeMo I 2025-01-31 07:42:29 wer:330] reference:ki ama paro ó shock mi
# [NeMo I 2025-01-31 07:42:29 wer:331] predicted:the
# [NeMo I 2025-01-31 07:42:58 wer:329]
#
# [NeMo I 2025-01-31 07:42:58 wer:330] reference:court ti schedule new date fún hearing tí preliminary objections
# [NeMo I 2025-01-31 07:42:58 wer:331] predicted:i
# [NeMo I 2025-01-31 07:43:26 wer:329]
#
# [NeMo I 2025-01-31 07:43:26 wer:330] reference:má to rí work not take care of ara ẹ
# [NeMo I 2025-01-31 07:43:26 wer:331] predicted:mo
# [NeMo I 2025-01-31 07:43:55 wer:329]
#
# [NeMo I 2025-01-31 07:43:55 wer:330] reference:let me know when ó bá ti ń lọ sí ile
# [NeMo I 2025-01-31 07:43:55 wer:331] predicted:the
# [NeMo I 2025-01-31 07:44:24 wer:329]
#
# [NeMo I 2025-01-31 07:44:24 wer:330] reference:education helps individual lati discover passion ati interest ara e
# [NeMo I 2025-01-31 07:44:24 wer:331] predicted:the
# [NeMo I 2025-01-31 07:44:53 wer:329]
#
# [NeMo I 2025-01-31 07:44:53 wer:330] reference:awon civil servants n gbadun new government yii
# [NeMo I 2025-01-31 07:44:53 wer:331] predicted:i
# [NeMo I 2025-01-31 07:45:22 wer:329]
#
# [NeMo I 2025-01-31 07:45:22 wer:330] reference:herbal mixture yi good gan fúñ inu rírún ati headache
# [NeMo I 2025-01-31 07:45:22 wer:331] predicted:i
# [NeMo I 2025-01-31 07:45:51 wer:329]
#
# [NeMo I 2025-01-31 07:45:51 wer:330] reference:mo se download the new album by adekunle gold mo kan fi si repeat for two days now
# [NeMo I 2025-01-31 07:45:51 wer:331] predicted:i the
# [NeMo I 2025-01-31 07:46:20 wer:329]
#
# [NeMo I 2025-01-31 07:46:20 wer:330] reference:you are trying to tu mi je
# [NeMo I 2025-01-31 07:46:20 wer:331] predicted:i mi
# [NeMo I 2025-01-31 07:46:48 wer:329]
#
# [NeMo I 2025-01-31 07:46:48 wer:330] reference:eyin ọmọ yorùbá come back to your culture the tradition of odùduwà
# [NeMo I 2025-01-31 07:46:48 wer:331] predicted:e mo o the
# [NeMo I 2025-01-31 07:47:17 wer:329]
#
# [NeMo I 2025-01-31 07:47:17 wer:330] reference:tola se ri the new music video by olamide visuals e are top notch
# [NeMo I 2025-01-31 07:47:17 wer:331] predicted:the the mi i
# [NeMo I 2025-01-31 07:47:46 wer:329]
#
# [NeMo I 2025-01-31 07:47:46 wer:330] reference:both isaiah and arogunyo n fe obirin kannaa
# [NeMo I 2025-01-31 07:47:46 wer:331] predicted:mo o
# [NeMo I 2025-01-31 07:48:15 wer:329]
#
# [NeMo I 2025-01-31 07:48:15 wer:330] reference:have just told my children's teacher pe ko sora fun awon omo mi o tori mo mó pè they can be annoying
# [NeMo I 2025-01-31 07:48:15 wer:331] predicted:i my mo mi mo mo i i
# [NeMo I 2025-01-31 07:48:43 wer:329]
#
# [NeMo I 2025-01-31 07:48:43 wer:330] reference:i want to own a rolex watch but ò wò n gaan
# [NeMo I 2025-01-31 07:48:43 wer:331] predicted:i e re o mo
# [NeMo I 2025-01-31 07:49:12 wer:329]
#
# [NeMo I 2025-01-31 07:49:12 wer:330] reference:they call him baba oba
# [NeMo I 2025-01-31 07:49:12 wer:331] predicted:the mi
# [NeMo I 2025-01-31 07:49:41 wer:329]
#
# [NeMo I 2025-01-31 07:49:41 wer:330] reference:even if i forget everything else oju re ni mi o le gbagbe
# [NeMo I 2025-01-31 07:49:41 wer:331] predicted:i ni wa o gbogbo ni mi
# [NeMo I 2025-01-31 07:50:10 wer:329]
#
# [NeMo I 2025-01-31 07:50:10 wer:330] reference:mo ti plan itinerary yen o ma cover major sights
# [NeMo I 2025-01-31 07:50:10 wer:331] predicted:ti it ti nia ni o wa mi ses
# [NeMo I 2025-01-31 07:50:39 wer:329]
#
# [NeMo I 2025-01-31 07:50:39 wer:330] reference:mo ti bẹ̀rẹ̀ morning exercise mi láti ọ̀sẹ̀ tó kọjá
# [NeMo I 2025-01-31 07:50:39 wer:331] predicted:mo ti b mo nies ni to gan
# [NeMo I 2025-01-31 07:51:07 wer:329]
#
# [NeMo I 2025-01-31 07:51:07 wer:330] reference:students feedback she pataki lati improve teaching methods
# [NeMo I 2025-01-31 07:51:07 wer:331] predicted:b lati f mi
# [NeMo I 2025-01-31 07:51:36 wer:329]
#
# [NeMo I 2025-01-31 07:51:36 wer:330] reference:tunde is an eleti kikun
# [NeMo I 2025-01-31 07:51:36 wer:331] predicted:that is i
# [NeMo I 2025-01-31 07:52:05 wer:329]
#
# [NeMo I 2025-01-31 07:52:05 wer:330] reference:tí ọwọ́ ẹ ò bá kà lifestyle dubai better stay in lagos
# [NeMo I 2025-01-31 07:52:05 wer:331] predicted:se o wa e my f to b e in
# [NeMo I 2025-01-31 07:52:33 wer:329]
#
# [NeMo I 2025-01-31 07:52:33 wer:330] reference:government ma ti block border
# [NeMo I 2025-01-31 07:52:33 wer:331] predicted:the b
# [NeMo I 2025-01-31 07:53:02 wer:329]
#
# [NeMo I 2025-01-31 07:53:02 wer:330] reference:the head of ile asofin lives in that area
# [NeMo I 2025-01-31 07:53:02 wer:331] predicted:the e of à o fi ni in that
# [NeMo I 2025-01-31 07:53:31 wer:329]
#
# [NeMo I 2025-01-31 07:53:31 wer:330] reference:action la ń jẹ
# [NeMo I 2025-01-31 07:53:31 wer:331] predicted:that my
# [NeMo I 2025-01-31 07:54:00 wer:329]
#
# [NeMo I 2025-01-31 07:54:00 wer:330] reference:we always pray together because ‘àdúrà ẹbí ń fún ìdílé ní ìtẹ̀síwájú
# [NeMo I 2025-01-31 07:54:00 wer:331] predicted:we of for to that d fi the ni is wa ni mi
# [NeMo I 2025-01-31 07:54:29 wer:329]
#
# [NeMo I 2025-01-31 07:54:29 wer:330] reference:lọlá used to work as an alájápá before joining the police force
# [NeMo I 2025-01-31 07:54:29 wer:331] predicted:i is of i for d the p s
# [NeMo I 2025-01-31 07:54:58 wer:329]
#
# [NeMo I 2025-01-31 07:54:58 wer:330] reference:elenu botoboto we will be saying something he will be saying something totally different
# [NeMo I 2025-01-31 07:54:58 wer:331] predicted:e gbogbo tó b to o be s soing i o be s some ti to that lef
# [NeMo I 2025-01-31 07:55:27 wer:329]
#
# [NeMo I 2025-01-31 07:55:27 wer:330] reference:i really nífẹ́ sí lágbájá's music
# [NeMo I 2025-01-31 07:55:27 wer:331] predicted:i we ni fe si b mi you
# [NeMo I 2025-01-31 07:55:56 wer:329]
#
# [NeMo I 2025-01-31 07:55:56 wer:330] reference:always brush your teeth kò tó sun ní àlé
# [NeMo I 2025-01-31 07:55:56 wer:331] predicted:we b tik to so ni
# [NeMo I 2025-01-31 07:56:24 wer:329]
#
# [NeMo I 2025-01-31 07:56:24 wer:330] reference:iwa buruku wa lowo those politicians
# [NeMo I 2025-01-31 07:56:24 wer:331] predicted:i wak do p s
# [NeMo I 2025-01-31 07:56:53 wer:329]
#
# [NeMo I 2025-01-31 07:56:53 wer:330] reference:o better if we resume work on weekend
# [NeMo I 2025-01-31 07:56:53 wer:331] predicted:o b you the wa ko
# [NeMo I 2025-01-31 07:57:22 wer:329]
#
# [NeMo I 2025-01-31 07:57:22 wer:330] reference:ìta ni kò spread aṣọ yẹn sì
# [NeMo I 2025-01-31 07:57:22 wer:331] predicted:e ni ko yen si
# [NeMo I 2025-01-31 07:57:50 wer:329]
#
# [NeMo I 2025-01-31 07:57:50 wer:330] reference:o lè ra ilera but you can buy healthy food which gives you ilera to peye
# [NeMo I 2025-01-31 07:57:50 wer:331] predicted:o le ma ile r gbogbo can gba lati for we ki ti i à to pe yen
# [NeMo I 2025-01-31 07:58:19 wer:329]
#
# [NeMo I 2025-01-31 07:58:19 wer:330] reference:what are the things you said i shouldn't buy for you tori ko si ówó lowo mi o
# [NeMo I 2025-01-31 07:58:19 wer:331] predicted:wa thating ti say that b for you to mi ko si o lo mi o
# [NeMo I 2025-01-31 07:58:48 wer:329]
#
# [NeMo I 2025-01-31 07:58:48 wer:330] reference:in these trying times i instruct everyone to stay safeeyi jẹ akoko ironu lori awọn nkan ti o yẹ ki a ṣe pataki niunu aye wa
# [NeMo I 2025-01-31 07:58:48 wer:331] predicted:the mys iro i want to st si j kok r loà wọn pe j ki ṣe pk ní wa
# [NeMo I 2025-01-31 07:59:17 wer:329]
#
# [NeMo I 2025-01-31 07:59:17 wer:330] reference:my son wants to become a dọkítà ní òla
# [NeMo I 2025-01-31 07:59:17 wer:331] predicted:my s was to be c to d it and
# [NeMo I 2025-01-31 07:59:46 wer:329]
#
# [NeMo I 2025-01-31 07:59:46 wer:330] reference:ìnáwó left and right ìgbà wo ló máa end
# [NeMo I 2025-01-31 07:59:46 wer:331] predicted:in w le andri d lo pe
# [NeMo I 2025-01-31 08:00:15 wer:329]
#
# [NeMo I 2025-01-31 08:00:15 wer:330] reference:taju ati tola are going to akure lola
# [NeMo I 2025-01-31 08:00:15 wer:331] predicted:t you that soa o loà
# [NeMo I 2025-01-31 08:00:43 wer:329]
#
# [NeMo I 2025-01-31 08:00:43 wer:330] reference:whenever i visit my grandmother she says ‘ẹbí mi ni orí ayé mi
# [NeMo I 2025-01-31 08:00:43 wer:331] predicted:o to is my grandmother ‘ ‘ is e mi ni
# [NeMo I 2025-01-31 08:01:12 wer:329]
#
# [NeMo I 2025-01-31 08:01:12 wer:330] reference:so mo pe citizens can participate ninu government audit
# [NeMo I 2025-01-31 08:01:12 wer:331] predicted:so mo pe si canpp ni government all
# [NeMo I 2025-01-31 08:01:41 wer:329]
#
# [NeMo I 2025-01-31 08:01:41 wer:330] reference:ìwọ tó wò aso white didn’t you know you are meant to eat more carefully
# [NeMo I 2025-01-31 08:01:41 wer:331] predicted:iwe wa to o o so waate theing know you andment to it mo pe f
# [NeMo I 2025-01-31 08:02:09 wer:329]
#
# [NeMo I 2025-01-31 08:02:09 wer:330] reference:it is the hospital staffs lo n se itoju fun awon sick people
# [NeMo I 2025-01-31 08:02:09 wer:331] predicted:it is the of st lo se d you fún si p
# [NeMo I 2025-01-31 08:02:38 wer:329]
#
# [NeMo I 2025-01-31 08:02:38 wer:330] reference:ati wa ni second semester
# [NeMo I 2025-01-31 08:02:38 wer:331] predicted:a wa ni se con ma
# [NeMo I 2025-01-31 08:03:07 wer:329]
#
# [NeMo I 2025-01-31 08:03:07 wer:330] reference:ṣó mo pè different tribe ló wà ní nàìjíríà
# [NeMo I 2025-01-31 08:03:07 wer:331] predicted:se p thef c lo and ni ja
# [NeMo I 2025-01-31 08:03:35 wer:329]
#
# [NeMo I 2025-01-31 08:03:35 wer:330] reference:are you still coming ni tabi plan e ti change
# [NeMo I 2025-01-31 08:03:35 wer:331] predicted:i you si c mi ni that p t
# [NeMo I 2025-01-31 08:04:04 wer:329]
#
# [NeMo I 2025-01-31 08:04:04 wer:330] reference:commissioner tun tun yen calm gan
# [NeMo I 2025-01-31 08:04:04 wer:331] predicted:c and to to yen e canm gan
# [NeMo I 2025-01-31 08:04:33 wer:329]
#
# [NeMo I 2025-01-31 08:04:33 wer:330] reference:mo fe get feedback on my work please e so mind yin
# [NeMo I 2025-01-31 08:04:33 wer:331] predicted:mo fe g f b on my work please e so ma
# [NeMo I 2025-01-31 08:05:03 wer:329]
#
# [NeMo I 2025-01-31 08:05:03 wer:330] reference:ranti lati back up awon data o wa important for protection
# [NeMo I 2025-01-31 08:05:03 wer:331] predicted:lo lati ti ba pp that o i p f re
# [NeMo I 2025-01-31 08:05:32 wer:329]
#
# [NeMo I 2025-01-31 08:05:32 wer:330] reference:ojogbon salaye lori rogbodiyan that happened in this country yesterday
# [NeMo I 2025-01-31 08:05:32 wer:331] predicted:j sa lorov that have the the c est
# Validation: |          | 0/? [00:00<?, ?it/s]
# [NeMo I 2025-01-31 08:05:51 wer:329]
#
# [NeMo I 2025-01-31 08:05:51 wer:330] reference:court ti instruct gbogbo parties láti file pretrial briefs ní deadline tí wọn set
# [NeMo I 2025-01-31 08:05:51 wer:331] predicted:c ti inro gbogbo par lati f prorier bs ni din ti won set
# [NeMo I 2025-01-31 08:05:51 wer:329]
#
# [NeMo I 2025-01-31 08:05:52 wer:330] reference:the nose of ọmọ ìkókó náà is dirty
# [NeMo I 2025-01-31 08:05:52 wer:331] predicted:the knows of ọmọ kò know is de
# [NeMo I 2025-01-31 08:05:52 wer:329]
#
# [NeMo I 2025-01-31 08:05:52 wer:330] reference:put three saki si ori first rice yen
# [NeMo I 2025-01-31 08:05:52 wer:331] predicted:st ch si o f st yen
# [NeMo I 2025-01-31 08:05:52 wer:329]
#
# [NeMo I 2025-01-31 08:05:52 wer:330] reference:create shortcuts lati pari awon ise yen kiakia
# [NeMo I 2025-01-31 08:05:52 wer:331] predicted:c c chcs lati ba wa ṣe e ki ki
# [NeMo I 2025-01-31 08:05:52 wer:329]
#
# [NeMo I 2025-01-31 08:05:52 wer:330] reference:olufemi's wrist ti kon
# [NeMo I 2025-01-31 08:05:52 wer:331] predicted:ol f is resst ti kan
# [NeMo I 2025-01-31 08:05:52 wer:329]
#
# [NeMo I 2025-01-31 08:05:52 wer:330] reference:akowe association ni brother vincent
# [NeMo I 2025-01-31 08:05:52 wer:331] predicted:à iwe are sation ni b
# [NeMo I 2025-01-31 08:05:53 wer:329]
#
# [NeMo I 2025-01-31 08:05:53 wer:330] reference:ata ni bolafade n sell to fi ran ara e lo si school
# [NeMo I 2025-01-31 08:05:53 wer:331] predicted:a ni b f sa to fi ara lo si school
# [NeMo I 2025-01-31 08:05:53 wer:329]
#
# [NeMo I 2025-01-31 08:05:53 wer:330] reference:if eyiowunmi likes ki o ma da awon eran lo si inside the bush
# [NeMo I 2025-01-31 08:05:53 wer:331] predicted:i yóò mi like ki ma dá iwe r lo si in i the b
# [NeMo I 2025-01-31 08:05:53 wer:329]
#
# [NeMo I 2025-01-31 08:05:53 wer:330] reference:mo fi charger mi ranṣẹ phone mi is dead
# [NeMo I 2025-01-31 08:05:53 wer:331] predicted:mo fi chá mir ṣe fun mi is d
# [NeMo I 2025-01-31 08:05:53 wer:329]
#
# [NeMo I 2025-01-31 08:05:53 wer:330] reference:i have been sleeping since àt’àná
# [NeMo I 2025-01-31 08:05:53 wer:331] predicted:i have be sing is a náà
# [NeMo I 2025-01-31 08:05:54 wer:329]
#
# [NeMo I 2025-01-31 08:05:54 wer:330] reference:many ẹ̀wẹ̀ kicked the bucket at arrival
# [NeMo I 2025-01-31 08:05:54 wer:331] predicted:mi e ki ti p get aver
# [NeMo I 2025-01-31 08:05:54 wer:329]
#
# [NeMo I 2025-01-31 08:05:54 wer:330] reference:this is the place tí mo ti ń ṣiṣẹ́
# [NeMo I 2025-01-31 08:05:54 wer:331] predicted:this is the please ti mo ti se ṣe
# [NeMo I 2025-01-31 08:05:54 wer:329]
#
# [NeMo I 2025-01-31 08:05:54 wer:330] reference:bawo ni ọkùnrin ṣe màá wọ́ lace material
# [NeMo I 2025-01-31 08:05:54 wer:331] predicted:ba wa ni o kr ṣe ma wa l má
# [NeMo I 2025-01-31 08:05:54 wer:329]
#
# [NeMo I 2025-01-31 08:05:54 wer:330] reference:ọmọ iléẹjọ́ náà n beere fún compensation fún damages tí ó ṣẹlẹ̀
# [NeMo I 2025-01-31 08:05:54 wer:331] predicted:ọmọm le i j on b fun cation fun ds ti o ṣele
# [NeMo I 2025-01-31 08:05:55 wer:329]
#
# [NeMo I 2025-01-31 08:05:55 wer:330] reference:do not relent o maà je ki wón overtake é
# [NeMo I 2025-01-31 08:05:55 wer:331] predicted:do not rem to ma je ki wọn wa ti e
# [NeMo I 2025-01-31 08:05:55 wer:329]
#
# [NeMo I 2025-01-31 08:05:55 wer:330] reference:wa check files fun missing documents i need all sorted
# [NeMo I 2025-01-31 08:05:55 wer:331] predicted:wa check fs for meing government i need always sed
# [NeMo I 2025-01-31 08:05:55 wer:329]
#
# [NeMo I 2025-01-31 08:05:55 wer:330] reference:abbey ati baba ni meeting yen will happen
# [NeMo I 2025-01-31 08:05:55 wer:331] predicted:à à bá ni mi yen iwe
# [NeMo I 2025-01-31 08:05:55 wer:329]
#
# [NeMo I 2025-01-31 08:05:55 wer:330] reference:check your email mo ti send important information kan
# [NeMo I 2025-01-31 08:05:55 wer:331] predicted:check your i mi mo s important f kan
# [NeMo I 2025-01-31 08:05:56 wer:329]
#
# [NeMo I 2025-01-31 08:05:56 wer:330] reference:manifesto yen simple abi promises ni gbogbo e
# [NeMo I 2025-01-31 08:05:56 wer:331] predicted:my f to yen si a pro ni gbogbo gbogbo
# [NeMo I 2025-01-31 08:05:56 wer:329]
#
# [NeMo I 2025-01-31 08:05:56 wer:330] reference:literacy level mi high gan
# [NeMo I 2025-01-31 08:05:56 wer:331] predicted:theit si lev mi i ko
# [NeMo I 2025-01-31 08:05:56 wer:329]
#
# [NeMo I 2025-01-31 08:05:56 wer:330] reference:oya wake up
# [NeMo I 2025-01-31 08:05:56 wer:331] predicted:o iwe ko
# [NeMo I 2025-01-31 08:05:56 wer:329]
#
# [NeMo I 2025-01-31 08:05:56 wer:330] reference:omo coach yen strict the exercise was intense
# [NeMo I 2025-01-31 08:05:56 wer:331] predicted:mo ko yen st the is was in ins
# [NeMo I 2025-01-31 08:05:57 wer:329]
#
# [NeMo I 2025-01-31 08:05:57 wer:330] reference:what can i do tí ó má fi understand pé mo like ẹ gan
# [NeMo I 2025-01-31 08:05:57 wer:331] predicted:what can i do tí o ma fi o that st pé mo like g gan
# [NeMo I 2025-01-31 08:05:57 wer:329]
#
# [NeMo I 2025-01-31 08:05:57 wer:330] reference:mo ni night class and it's always interesting i get to learn new things late into the night awon oremi tu ma gbe ounje wa
# [NeMo I 2025-01-31 08:05:57 wer:331] predicted:mo need c and’ always it i get the li new ts li in the li and wa re to my iwe o j wa
# [NeMo I 2025-01-31 08:05:57 wer:329]
#
# [NeMo I 2025-01-31 08:05:57 wer:330] reference:i have never been to ilu abuja before
# [NeMo I 2025-01-31 08:05:57 wer:331] predicted:i have iwe lo before
# [NeMo I 2025-01-31 08:05:57 wer:329]
#
# [NeMo I 2025-01-31 08:05:57 wer:330] reference:akara ati ogi oyingbo is what my wife made that morning
# [NeMo I 2025-01-31 08:05:57 wer:331] predicted:à tí o g o in gbogbo is what my my me that man
# [NeMo I 2025-01-31 08:05:58 wer:329]
#
# [NeMo I 2025-01-31 08:05:58 wer:330] reference:mo ni tutorials on programming basics great for beginners
# [NeMo I 2025-01-31 08:05:58 wer:331] predicted:mo to t has on pro bs b for bes
# [NeMo I 2025-01-31 08:05:58 wer:329]
#
# [NeMo I 2025-01-31 08:05:58 wer:330] reference:our wife has moved to her ile oko
# [NeMo I 2025-01-31 08:05:58 wer:331] predicted:i wi has mo to a ile o
# [NeMo I 2025-01-31 08:05:58 wer:329]
#
# [NeMo I 2025-01-31 08:05:58 wer:330] reference:one important aspect of yoruba traditional literature is eréoníṣe àbáláyé which refers to indigenous performances
# [NeMo I 2025-01-31 08:05:58 wer:331] predicted:ẹ important has of you tra leit is e ni ṣe a y we a f to ins family
# [NeMo I 2025-01-31 08:05:59 wer:329]
#
# [NeMo I 2025-01-31 08:05:59 wer:330] reference:there are two ọmọ iṣẹ́ at your workplace
# [NeMo I 2025-01-31 08:05:59 wer:331] predicted:they are to ọmọ ṣe a your b pl
# [NeMo I 2025-01-31 08:05:59 wer:329]
#
# [NeMo I 2025-01-31 08:05:59 wer:330] reference:eyin omo congratulations to you o ire bayii laa ma barawa sè o
# [NeMo I 2025-01-31 08:05:59 wer:331] predicted:i mo grandmother your iwe máa wa ṣe
# [NeMo I 2025-01-31 08:05:59 wer:329]
#
# [NeMo I 2025-01-31 08:05:59 wer:330] reference:o ti check the time for the flight we can’t afford to miss it
# [NeMo I 2025-01-31 08:05:59 wer:331] predicted:o ti check the my for the f we can for to me it
# [NeMo I 2025-01-31 08:05:59 wer:329]
#
# [NeMo I 2025-01-31 08:05:59 wer:330] reference:o ti sign the contract for the house je kin mo before moving in
# [NeMo I 2025-01-31 08:05:59 wer:331] predicted:o ti s the c for the hes jeing mo before moing in
# [NeMo I 2025-01-31 08:06:00 wer:329]
#
# [NeMo I 2025-01-31 08:06:00 wer:330] reference:the temple of ọlọ́bùn ni ilé ìjọsìn àwọn tósìn wà
# [NeMo I 2025-01-31 08:06:00 wer:331] predicted:the tell of ol gbogbo ni ile j si àwọn tó si wa
# [NeMo I 2025-01-31 08:06:00 wer:329]
#
# [NeMo I 2025-01-31 08:06:00 wer:330] reference:mo ti update settings o ye ki o work better now
# [NeMo I 2025-01-31 08:06:00 wer:331] predicted:mo ti of set o e ki work b now
# [NeMo I 2025-01-31 08:06:00 wer:329]
#
# [NeMo I 2025-01-31 08:06:00 wer:330] reference:package mi wa ni porch ma pick e up in the evening
# [NeMo I 2025-01-31 08:06:00 wer:331] predicted:p j mi wa ni p ma p ki in the ev
# [NeMo I 2025-01-31 08:06:00 wer:329]
#
# [NeMo I 2025-01-31 08:06:00 wer:330] reference:where is the igbako ti mo felo
# [NeMo I 2025-01-31 08:06:00 wer:331] predicted:we is the bá ko ti mo fẹ́
# [NeMo I 2025-01-31 08:06:01 wer:329]
#
# [NeMo I 2025-01-31 08:06:01 wer:330] reference:ti nba ti bó tà ní sín yí first thing to mo maà like lati sè ni pe kín change adapter charger mi
# [NeMo I 2025-01-31 08:06:01 wer:331] predicted:ti ti ba ti b t ni si yen fing ti mo ma lati latiation ni p se g that t ṣ j mi
# [NeMo I 2025-01-31 08:06:01 wer:329]
#
# [NeMo I 2025-01-31 08:06:01 wer:330] reference:i was praying nigba ti mó gbo ninu spirit mi pe son i am with you
# [NeMo I 2025-01-31 08:06:01 wer:331] predicted:i am p ni bá ti mo b speit mi pé so i a with you
# [NeMo I 2025-01-31 08:06:01 wer:329]
#
# ...
# [NeMo I 2025-01-31 17:48:30 wer:330] reference:mo fẹ́ se challenge days aso tí mo má wò but i don’t go out at all
# [NeMo I 2025-01-31 17:48:30 wer:331] predicted:mo fẹ́ se challeng days but ti mo ma wò but i don’t go out at all
# [NeMo I 2025-01-31 17:49:00 wer:329]
#
# [NeMo I 2025-01-31 17:49:00 wer:330] reference:government fe introduce social justice initiative tun tun
# [NeMo I 2025-01-31 17:49:00 wer:331] predicted:government fe introduce social justice initiative tunún tun
# [NeMo I 2025-01-31 17:49:29 wer:329]
#
# [NeMo I 2025-01-31 17:49:29 wer:330] reference:you are beautiful naturally but o nílò láti má lo lipgloss lẹ́ẹ̀kọ̀kan
# [NeMo I 2025-01-31 17:49:29 wer:331] predicted:you are beautiful naturally but o níò láti ti má lo lipgloss si ẹ̀kkan
# [NeMo I 2025-01-31 17:49:59 wer:329]
#
# [NeMo I 2025-01-31 17:49:59 wer:330] reference:we gather together every holiday because ‘kò sí ibi tó dàbí ilé
# [NeMo I 2025-01-31 17:49:59 wer:331] predicted:we gather together every holiday because ‘kò sí ibi tó dàbí ilé
# [NeMo I 2025-01-31 17:50:28 wer:329]
#
# [NeMo I 2025-01-31 17:50:28 wer:330] reference:ijoba can be federal
# [NeMo I 2025-01-31 17:50:28 wer:331] predicted:ijoba can be federal
# [NeMo I 2025-01-31 17:50:58 wer:329]
#
# [NeMo I 2025-01-31 17:50:58 wer:330] reference:chemistry and biology je necessary courses fun awon science students
# [NeMo I 2025-01-31 17:50:58 wer:331] predicted:chechmistry and biogy un necessary courses fun awon science stud
# [NeMo I 2025-01-31 17:51:27 wer:329]
#
# [NeMo I 2025-01-31 17:51:27 wer:330] reference:e lo keyboard shortcuts lati save time it’s very helpful
# [NeMo I 2025-01-31 17:51:27 wer:331] predicted:e lo keyboard shortcuts lati save time it’s very helpful
# [NeMo I 2025-01-31 17:51:56 wer:329]
#
# [NeMo I 2025-01-31 17:51:56 wer:330] reference:i'm thinking of the gift ti mó lé fun awon newly wedded couple
# [NeMo I 2025-01-31 17:51:56 wer:331] predicted:i'm thinking of the gfts ti mó lé fun awon newly wedded couple
# [NeMo I 2025-01-31 17:52:26 wer:329]
#
# [NeMo I 2025-01-31 17:52:26 wer:330] reference:tani vendor fun jewelry yen
# [NeMo I 2025-01-31 17:52:26 wer:331] predicted:tani vendor fun jewelry yen
# [NeMo I 2025-01-31 17:52:55 wer:329]
#
# [NeMo I 2025-01-31 17:52:55 wer:330] reference:take an umbrella orun yen ti poju
# [NeMo I 2025-01-31 17:52:55 wer:331] predicted:take an umbrella orun yen ti poju
# [NeMo I 2025-01-31 17:53:25 wer:329]
#
# [NeMo I 2025-01-31 17:53:25 wer:330] reference:ṣé lóòótọ́ ni pé some people now do tongue piercing
# [NeMo I 2025-01-31 17:53:25 wer:331] predicted:ṣé lóòótọ́ ní pé some people now do tong piisent
# [NeMo I 2025-01-31 17:53:55 wer:329]
#
# [NeMo I 2025-01-31 17:53:55 wer:330] reference:which ile ifowopamo are you using na
# [NeMo I 2025-01-31 17:53:55 wer:331] predicted:which ile ifowopamo you us la na
# [NeMo I 2025-01-31 17:54:25 wer:329]
#
# [NeMo I 2025-01-31 17:54:25 wer:330] reference:my grandmother says ‘ẹni tó ní ẹbí tó fẹ́ràn rẹ̀ yóò dágbére ni ayo
# [NeMo I 2025-01-31 17:54:25 wer:331] predicted:my grandmother says ‘ẹni tó ní ẹbí ń fẹ́ràn rẹ yóò dá gbre ní ayé
# [NeMo I 2025-01-31 17:54:55 wer:329]
#
# [NeMo I 2025-01-31 17:54:55 wer:330] reference:orin chiffchaff maa n wa from a favoured prominent vantage point
# [NeMo I 2025-01-31 17:54:55 wer:331] predicted:orin chiffchff ma n wa from a favoured promin vantage point
# [NeMo I 2025-01-31 17:55:24 wer:329]
#
# [NeMo I 2025-01-31 17:55:24 wer:330] reference:have you seen the reason why he can't easily find a close ọ̀rẹ́kùnrin
# [NeMo I 2025-01-31 17:55:24 wer:331] predicted:have you seen the reason why he can't easily find a clo ọ̀rẹ́kùnrin
# Validation: |          | 0/? [00:00<?, ?it/s]
# [NeMo I 2025-01-31 17:55:43 wer:329]
#
# [NeMo I 2025-01-31 17:55:43 wer:330] reference:court ti instruct gbogbo parties láti file pretrial briefs ní deadline tí wọn set
# [NeMo I 2025-01-31 17:55:43 wer:331] predicted:court ti instruct gbogbo parties láti file pretrial briefs ní deadline tí wọn set
# [NeMo I 2025-01-31 17:55:43 wer:329]
#
# [NeMo I 2025-01-31 17:55:43 wer:330] reference:the nose of ọmọ ìkókó náà is dirty
# [NeMo I 2025-01-31 17:55:43 wer:331] predicted:the hse of ọmọ ikokoa is dirty
# [NeMo I 2025-01-31 17:55:44 wer:329]
#
# [NeMo I 2025-01-31 17:55:44 wer:330] reference:put three saki si ori first rice yen
# [NeMo I 2025-01-31 17:55:44 wer:331] predicted:put three saki si ori fresirst rice yen
# [NeMo I 2025-01-31 17:55:44 wer:329]
#
# [NeMo I 2025-01-31 17:55:44 wer:330] reference:create shortcuts lati pari awon ise yen kiakia
# [NeMo I 2025-01-31 17:55:44 wer:331] predicted:create shortcuts lati pari awon ise yen ki aa
# [NeMo I 2025-01-31 17:55:44 wer:329]
#
# [NeMo I 2025-01-31 17:55:44 wer:330] reference:olufemi's wrist ti kon
# [NeMo I 2025-01-31 17:55:44 wer:331] predicted:olufeémin's wrist ti kon
# [NeMo I 2025-01-31 17:55:44 wer:329]
#
# [NeMo I 2025-01-31 17:55:44 wer:330] reference:akowe association ni brother vincent
# [NeMo I 2025-01-31 17:55:44 wer:331] predicted:àowe association ni brother vincent
# [NeMo I 2025-01-31 17:55:45 wer:329]
#
# [NeMo I 2025-01-31 17:55:45 wer:330] reference:ata ni bolafade n sell to fi ran ara e lo si school
# [NeMo I 2025-01-31 17:55:45 wer:331] predicted:ata ni bolafade n sell to fi ran ara e ló si school
# [NeMo I 2025-01-31 17:55:45 wer:329]
#
# [NeMo I 2025-01-31 17:55:45 wer:330] reference:if eyiowunmi likes ki o ma da awon eran lo si inside the bush
# [NeMo I 2025-01-31 17:55:45 wer:331] predicted:if eyiowmi likes ki o ma dawean lo si inside the bush
# [NeMo I 2025-01-31 17:55:45 wer:329]
#
# [NeMo I 2025-01-31 17:55:45 wer:330] reference:mo fi charger mi ranṣẹ phone mi is dead
# [NeMo I 2025-01-31 17:55:45 wer:331] predicted:mo fi charger mi ranṣẹ phone mi is dead
# [NeMo I 2025-01-31 17:55:45 wer:329]
#
# [NeMo I 2025-01-31 17:55:45 wer:330] reference:i have been sleeping since àt’àná
# [NeMo I 2025-01-31 17:55:45 wer:331] predicted:i have been sleeping since àtá
# [NeMo I 2025-01-31 17:55:45 wer:329]
#
# [NeMo I 2025-01-31 17:55:45 wer:330] reference:many ẹ̀wẹ̀ kicked the bucket at arrival
# [NeMo I 2025-01-31 17:55:46 wer:331] predicted:many ewé kcked ti bucket at arrival
# [NeMo I 2025-01-31 17:55:46 wer:329]
#
# [NeMo I 2025-01-31 17:55:46 wer:330] reference:this is the place tí mo ti ń ṣiṣẹ́
# [NeMo I 2025-01-31 17:55:46 wer:331] predicted:this is the place ti mo ti n sise
# [NeMo I 2025-01-31 17:55:46 wer:329]
#
# [NeMo I 2025-01-31 17:55:46 wer:330] reference:bawo ni ọkùnrin ṣe màá wọ́ lace material
# [NeMo I 2025-01-31 17:55:46 wer:331] predicted:bawo ni ọkùnrin ṣe máa wọ́ lace materi
# [NeMo I 2025-01-31 17:55:46 wer:329]
#
# [NeMo I 2025-01-31 17:55:46 wer:330] reference:ọmọ iléẹjọ́ náà n beere fún compensation fún damages tí ó ṣẹlẹ̀
# [NeMo I 2025-01-31 17:55:46 wer:331] predicted:ọmọ iléẹjọ́ náà bè fún compensation fún damages tí ó ṣeẹlẹ̀
# [NeMo I 2025-01-31 17:55:46 wer:329]
#
# [NeMo I 2025-01-31 17:55:46 wer:330] reference:do not relent o maà je ki wón overtake é
# [NeMo I 2025-01-31 17:55:46 wer:331] predicted:do not relent o maà je ki wón overtake é
# [NeMo I 2025-01-31 17:55:47 wer:329]
#
# [NeMo I 2025-01-31 17:55:47 wer:330] reference:wa check files fun missing documents i need all sorted
# [NeMo I 2025-01-31 17:55:47 wer:331] predicted:wa check files fun missing documents i need all sed
# [NeMo I 2025-01-31 17:55:47 wer:329]
#
# [NeMo I 2025-01-31 17:55:47 wer:330] reference:abbey ati baba ni meeting yen will happen
# [NeMo I 2025-01-31 17:55:47 wer:331] predicted:ad tí baba ni meeting yen will happen
# [NeMo I 2025-01-31 17:55:47 wer:329]
#
# [NeMo I 2025-01-31 17:55:47 wer:330] reference:check your email mo ti send important information kan
# [NeMo I 2025-01-31 17:55:47 wer:331] predicted:check your email mo ti send important information kan
# [NeMo I 2025-01-31 17:55:48 wer:329]
#
# [NeMo I 2025-01-31 17:55:48 wer:330] reference:manifesto yen simple abi promises ni gbogbo e
# [NeMo I 2025-01-31 17:55:48 wer:331] predicted:manifesto yen simple abi promises ni gbogbo e
# [NeMo I 2025-01-31 17:55:48 wer:329]
#
# [NeMo I 2025-01-31 17:55:48 wer:330] reference:literacy level mi high gan
# [NeMo I 2025-01-31 17:55:48 wer:331] predicted:literaacy level mi high gan
# [NeMo I 2025-01-31 17:55:48 wer:329]
#
# [NeMo I 2025-01-31 17:55:48 wer:330] reference:oya wake up
# [NeMo I 2025-01-31 17:55:48 wer:331] predicted:oya wake up
# [NeMo I 2025-01-31 17:55:48 wer:329]
#
# [NeMo I 2025-01-31 17:55:48 wer:330] reference:omo coach yen strict the exercise was intense
# [NeMo I 2025-01-31 17:55:48 wer:331] predicted:omo coach yen strict the exercise was intense
# [NeMo I 2025-01-31 17:55:49 wer:329]
#
# [NeMo I 2025-01-31 17:55:49 wer:330] reference:what can i do tí ó má fi understand pé mo like ẹ gan
# [NeMo I 2025-01-31 17:55:49 wer:331] predicted:what can i do tí ó má fi understand pé mo like ẹ gan
# [NeMo I 2025-01-31 17:55:49 wer:329]
#
# [NeMo I 2025-01-31 17:55:49 wer:330] reference:mo ni night class and it's always interesting i get to learn new things late into the night awon oremi tu ma gbe ounje wa
# [NeMo I 2025-01-31 17:55:49 wer:331] predicted:mo ni night's class and iten's always interesting i get to learn new things late in the night awon oremi to maan gbe ounje wa
# [NeMo I 2025-01-31 17:55:49 wer:329]
#
# [NeMo I 2025-01-31 17:55:49 wer:330] reference:i have never been to ilu abuja before
# [NeMo I 2025-01-31 17:55:49 wer:331] predicted:i have never been to ilu abuja before
# [NeMo I 2025-01-31 17:55:49 wer:329]
#
# [NeMo I 2025-01-31 17:55:49 wer:330] reference:akara ati ogi oyingbo is what my wife made that morning
# [NeMo I 2025-01-31 17:55:49 wer:331] predicted:akara ati ogi oyiningboe is what my wife made this morning
# [NeMo I 2025-01-31 17:55:50 wer:329]
#
# [NeMo I 2025-01-31 17:55:50 wer:330] reference:mo ni tutorials on programming basics great for beginners
# [NeMo I 2025-01-31 17:55:50 wer:331] predicted:mo ni tutorials for programming basicsreatreat for beginners
# [NeMo I 2025-01-31 17:55:50 wer:329]
#
# [NeMo I 2025-01-31 17:55:50 wer:330] reference:our wife has moved to her ile oko
# [NeMo I 2025-01-31 17:55:50 wer:331] predicted:our wife has moved to her ile oko
# [NeMo I 2025-01-31 17:55:50 wer:329]
#
# [NeMo I 2025-01-31 17:55:50 wer:330] reference:one important aspect of yoruba traditional literature is eréoníṣe àbáláyé which refers to indigenous performances
# [NeMo I 2025-01-31 17:55:50 wer:331] predicted:one important aspectt of yoruba tradition literature is erere oníse àalaye which refer to indigenuous performances
# [NeMo I 2025-01-31 17:55:50 wer:329]
#
# [NeMo I 2025-01-31 17:55:50 wer:330] reference:there are two ọmọ iṣẹ́ at your workplace
# [NeMo I 2025-01-31 17:55:50 wer:331] predicted:there are two ọmọṣẹ́ at your workplace
# [NeMo I 2025-01-31 17:55:51 wer:329]
#
# [NeMo I 2025-01-31 17:55:51 wer:330] reference:eyin omo congratulations to you o ire bayii laa ma barawa sè o
# [NeMo I 2025-01-31 17:55:51 wer:331] predicted:eyin omo congratulations to you ire bayii la ma ba wa s o
# [NeMo I 2025-01-31 17:55:51 wer:329]
#
# [NeMo I 2025-01-31 17:55:51 wer:330] reference:o ti check the time for the flight we can’t afford to miss it
# [NeMo I 2025-01-31 17:55:51 wer:331] predicted:o ti check the time for the flight we can’t afford to miss it
# [NeMo I 2025-01-31 17:55:51 wer:329]
#
# [NeMo I 2025-01-31 17:55:51 wer:330] reference:o ti sign the contract for the house je kin mo before moving in
# [NeMo I 2025-01-31 17:55:51 wer:331] predicted:o ti sign the contract for the house je kin mo before moving in
# [NeMo I 2025-01-31 17:55:51 wer:329]
#
# [NeMo I 2025-01-31 17:55:51 wer:330] reference:the temple of ọlọ́bùn ni ilé ìjọsìn àwọn tósìn wà
# [NeMo I 2025-01-31 17:55:51 wer:331] predicted:the temple of ọlọ́bùn ni ilé ìjọs àwọn tósìn wà
# [NeMo I 2025-01-31 17:55:52 wer:329]
#
# [NeMo I 2025-01-31 17:55:52 wer:330] reference:mo ti update settings o ye ki o work better now
# [NeMo I 2025-01-31 17:55:52 wer:331] predicted:mo ti update settings o ye ki o work better now
# [NeMo I 2025-01-31 17:55:52 wer:329]
#
# [NeMo I 2025-01-31 17:55:52 wer:330] reference:package mi wa ni porch ma pick e up in the evening
# [NeMo I 2025-01-31 17:55:52 wer:331] predicted:package mi ba ni porch ma pick e up in the evening
# [NeMo I 2025-01-31 17:55:52 wer:329]
#
# [NeMo I 2025-01-31 17:55:52 wer:330] reference:where is the igbako ti mo felo
# [NeMo I 2025-01-31 17:55:52 wer:331] predicted:where is the igbako ti mo felo
# [NeMo I 2025-01-31 17:55:52 wer:329]
#
# [NeMo I 2025-01-31 17:55:52 wer:330] reference:ti nba ti bó tà ní sín yí first thing to mo maà like lati sè ni pe kín change adapter charger mi
# [NeMo I 2025-01-31 17:55:52 wer:331] predicted:ti n ba ti bter nisi yi first thing ti mó maà like lati se ni pe kin change daata charger mi
# [NeMo I 2025-01-31 17:55:53 wer:329]
#
# [NeMo I 2025-01-31 17:55:53 wer:330] reference:i was praying nigba ti mó gbo ninu spirit mi pe son i am with you
# [NeMo I 2025-01-31 17:55:53 wer:331] predicted:ien am praying nigba ti mó gbo ninu spirit mi pe soon i am with you
# [NeMo I 2025-01-31 17:55:53 wer:329]
#
# [NeMo I 2025-01-31 17:55:53 wer:330] reference:gómìnà sọ pé ká mà beru a new world is coming
# [NeMo I 2025-01-31 17:55:53 wer:331] predicted:gómìnà sọ pé ká má beere a new world is coming
# [NeMo I 2025-01-31 17:55:53 wer:329]
#
# [NeMo I 2025-01-31 17:55:53 wer:330] reference:i don't know boya ó ma le bami so fúñ babe mi pe a fe lo si beach ni next week
# [NeMo I 2025-01-31 17:55:53 wer:331] predicted:i donn't know boya ó ma le ba mi so fun babe mi pe a fe lo si bh ni next week
# [NeMo I 2025-01-31 17:55:53 wer:329]
#
# [NeMo I 2025-01-31 17:55:53 wer:330] reference:authentic ni product yẹn
# [NeMo I 2025-01-31 17:55:53 wer:331] predicted:authentic ni product yẹn
# [NeMo I 2025-01-31 17:55:54 wer:329]
#
# [NeMo I 2025-01-31 17:55:54 wer:330] reference:i love ajibola’s dress sense ó máa ń always ṣe irun ìbílẹ̀ ó dẹ̀ máa ń fit ẹ
# [NeMo I 2025-01-31 17:55:54 wer:331] predicted:i love àjibllen’s dressense ó máaán always ṣe irun ìbílẹ̀ ó d máa ń fat ẹ
# [NeMo I 2025-01-31 17:55:54 wer:329]
#
# [NeMo I 2025-01-31 17:55:54 wer:330] reference:we want to work a kìí ṣ’ọ̀lẹ
# [NeMo I 2025-01-31 17:55:54 wer:331] predicted:we want to work ainìíually
# [NeMo I 2025-01-31 17:55:54 wer:329]
#
# [NeMo I 2025-01-31 17:55:54 wer:330] reference:students must be disciplined nitori pe ifarada ati iṣẹ takuntakun n gbe wa si ibi ti a fẹ
# [NeMo I 2025-01-31 17:55:54 wer:331] predicted:students must be disciplined nitorí pé ìaradà àti iseẹ́ tàkún tkún gbé wa si ibi tí a fẹ
# [NeMo I 2025-01-31 17:55:54 wer:329]
#
# [NeMo I 2025-01-31 17:55:54 wer:330] reference:it is very good ki a mama gba adura ti a ba ji
# [NeMo I 2025-01-31 17:55:54 wer:331] predicted:it is very good ki a ma ma gbadura ti a baji
# [NeMo I 2025-01-31 17:55:55 wer:329]
#
# [NeMo I 2025-01-31 17:55:55 wer:330] reference:the members kò káàárẹ̀ láti máa wá sí ìpàdé
# [NeMo I 2025-01-31 17:55:55 wer:331] predicted:the members kò kaáare láti máa wa si ìpdé
# [NeMo I 2025-01-31 17:55:55 wer:329]
#
# [NeMo I 2025-01-31 17:55:55 wer:330] reference:president wa yìí strict ganan
# [NeMo I 2025-01-31 17:55:55 wer:331] predicted:president wa yìí strict gan
# [NeMo I 2025-01-31 17:55:55 wer:329]
#
# [NeMo I 2025-01-31 17:55:55 wer:330] reference:olùdárí ilẹ̀wòsàn yẹn is very strict
# [NeMo I 2025-01-31 17:55:55 wer:331] predicted:oldárí iléwòsàn yẹn is very strict
# [NeMo I 2025-01-31 17:55:55 wer:329]
#
# [NeMo I 2025-01-31 17:55:55 wer:330] reference:stella said ebi n pa oun
# [NeMo I 2025-01-31 17:55:55 wer:331] predicted:stella said ìbí ń pa oun
# [NeMo I 2025-01-31 17:55:56 wer:329]
#
# [NeMo I 2025-01-31 17:55:56 wer:330] reference:gomína wà n treat examination malpractices seriously
# [NeMo I 2025-01-31 17:55:56 wer:331] predicted:gomína wà n treat examinational practices seriously
# [NeMo I 2025-01-31 17:55:56 wer:329]
#
# [NeMo I 2025-01-31 17:55:56 wer:330] reference:this is the place tí mo ti ń ṣiṣẹ́
# [NeMo I 2025-01-31 17:55:56 wer:331] predicted:this is the place ti mo ti n sise

# %%
# Setup test dataset
pretrained_model.setup_test_data(test_data_config=config.test_ds)
results = trainer.test(pretrained_model)
print(results)
# Out:
# [NeMo I 2025-01-31 17:56:06 collections:201] Dataset loaded with 1614 files totalling 1.93 hours
# [NeMo I 2025-01-31 17:56:06 collections:202] 0 files were filtered totalling 0.00 hours
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: |          | 0/? [00:00<?, ?it/s]
# [NeMo I 2025-01-31 17:56:08 wer:329]
#
# [NeMo I 2025-01-31 17:56:08 wer:330] reference:fredrick ma wa violent gan whenever he takes alcohol
# [NeMo I 2025-01-31 17:56:08 wer:331] predicted:fedbric ma wa vallebe whenever you taes grow
# [NeMo I 2025-01-31 17:56:08 wer:329]
#
# [NeMo I 2025-01-31 17:56:08 wer:330] reference:charge it to my card o better ju cash
# [NeMo I 2025-01-31 17:56:08 wer:331] predicted:chade to my card o gbọ́ dá ju cash
# [NeMo I 2025-01-31 17:56:08 wer:329]
#
# [NeMo I 2025-01-31 17:56:08 wer:330] reference:phone ẹ wá lórí table
# [NeMo I 2025-01-31 17:56:08 wer:331] predicted:ston e wa lori tableor
# [NeMo I 2025-01-31 17:56:08 wer:329]
#
# [NeMo I 2025-01-31 17:56:08 wer:330] reference:the latest style ti àwọn youth wo báyìí nice gan
# [NeMo I 2025-01-31 17:56:08 wer:331] predicted:the latest ight ti awon youth wore bái or nize gan
# [NeMo I 2025-01-31 17:56:08 wer:329]
#
# [NeMo I 2025-01-31 17:56:08 wer:330] reference:what is this thing that looks like aràn
# [NeMo I 2025-01-31 17:56:08 wer:331] predicted:what is this thing that looks like aràn
# [NeMo I 2025-01-31 17:56:08 wer:329]
#
# [NeMo I 2025-01-31 17:56:08 wer:330] reference:the doctor sọ pé àwọn oní gbèsè rẹ̀
# [NeMo I 2025-01-31 17:56:08 wer:331] predicted:doctor sọ pé àwọnígbè ro
# [NeMo I 2025-01-31 17:56:08 wer:329]
#
# [NeMo I 2025-01-31 17:56:08 wer:330] reference:ṣaléwá wore an àǹkárá with seven different patterns
# [NeMo I 2025-01-31 17:56:08 wer:331] predicted:saalw wore an àr with ven different patterns
# [NeMo I 2025-01-31 17:56:09 wer:329]
#
# [NeMo I 2025-01-31 17:56:09 wer:330] reference:se gbogbo tasks tí ó jọ ara wọn papo bí email ati data entry lati avoid context switching
# [NeMo I 2025-01-31 17:56:09 wer:331] predicted:se gbogbo tasks ti o ojo ara won pao ni email lati data entry lati avoid obtext switching
# [NeMo I 2025-01-31 17:56:09 wer:329]
#
# [NeMo I 2025-01-31 17:56:09 wer:330] reference:table manners wa very important
# [NeMo I 2025-01-31 17:56:09 wer:331] predicted:vble manners wa very important
# [NeMo I 2025-01-31 17:56:09 wer:329]
#
# [NeMo I 2025-01-31 17:56:09 wer:330] reference:labisi farted ni igba ti she was eating
# [NeMo I 2025-01-31 17:56:09 wer:331] predicted:labisi farted ni igba ti she was eating
# [NeMo I 2025-01-31 17:56:09 wer:329]
#
# [NeMo I 2025-01-31 17:56:09 wer:330] reference:kò ní mú ọgbọ́n wá if we don't return the remaining money
# [NeMo I 2025-01-31 17:56:09 wer:331] predicted:kò ni mo ọjọ́ wa it will don’t return ther remim morning
# [NeMo I 2025-01-31 17:56:09 wer:329]
#
# [NeMo I 2025-01-31 17:56:09 wer:330] reference:the omi has danu it was juwon that gba mi sile when the bukata was too much fun mi
# [NeMo I 2025-01-31 17:56:09 wer:331] predicted:the o male has done on it wasju won that gba ni suil he when the pkta was so much funmi
# [NeMo I 2025-01-31 17:56:09 wer:329]
#
# [NeMo I 2025-01-31 17:56:09 wer:330] reference:the name of the group ni ìfẹ́lódùn
# [NeMo I 2025-01-31 17:56:09 wer:331] predicted:the name of the group ni ìfẹ́lódùn
# [NeMo I 2025-01-31 17:56:09 wer:329]
#
# [NeMo I 2025-01-31 17:56:09 wer:330] reference:désọ́lá went to bath at the river
# [NeMo I 2025-01-31 17:56:09 wer:331] predicted:desla went to buy ada
# [NeMo I 2025-01-31 17:56:09 wer:329]
#
# [NeMo I 2025-01-31 17:56:09 wer:330] reference:do you know the reason tí mo fi sọ bẹ́ ẹ̀
# [NeMo I 2025-01-31 17:56:09 wer:331] predicted:did you know of the r deal ti mo ti sgb e
# [NeMo I 2025-01-31 17:56:09 wer:329]
#
# [NeMo I 2025-01-31 17:56:09 wer:330] reference:my grandmother says ‘ẹbí tí ó bá ní àlàáfíà á máa ṣàṣeyọrí ní gbogbo ohun
# [NeMo I 2025-01-31 17:56:09 wer:331] predicted:my grandmother says ‘ẹbí tí ó bá ní àlàáfíà á máa fṣeyọrí ni gbogbo ohun
# [NeMo I 2025-01-31 17:56:10 wer:329]
#
# [NeMo I 2025-01-31 17:56:10 wer:330] reference:i'm not playing o òdodo ọ̀rọ̀ ni
# [NeMo I 2025-01-31 17:56:10 wer:331] predicted:i' am not playing o ododo oro ni
# [NeMo I 2025-01-31 17:56:10 wer:329]
#
# [NeMo I 2025-01-31 17:56:10 wer:330] reference:we told him ṣùgbọ́n he didn't listen
# [NeMo I 2025-01-31 17:56:10 wer:331] predicted:we told him sugbon he didn't listen
# [NeMo I 2025-01-31 17:56:10 wer:329]
#
# [NeMo I 2025-01-31 17:56:10 wer:330] reference:all of them were fori bale fun oluwa lati morning di night
# [NeMo I 2025-01-31 17:56:10 wer:331] predicted:all of them were fori bale fun oluwa lati morning di night
# [NeMo I 2025-01-31 17:56:10 wer:329]
#
# [NeMo I 2025-01-31 17:56:10 wer:330] reference:it is very hard ija ore
# [NeMo I 2025-01-31 17:56:10 wer:331] predicted:it is very hard ija ore
# [NeMo I 2025-01-31 17:56:10 wer:329]
#
# [NeMo I 2025-01-31 17:56:10 wer:330] reference:taye mo iwe more than kehinde
# [NeMo I 2025-01-31 17:56:10 wer:331] predicted:taye mo pé more than keinde
# [NeMo I 2025-01-31 17:56:10 wer:329]
#
# [NeMo I 2025-01-31 17:56:10 wer:330] reference:some people believe pé bí èyàn ṣe ń grow older ló ṣe jẹ́ kó gain more understanding
# [NeMo I 2025-01-31 17:56:10 wer:331] predicted:some people believe pé bi ẹ̀yàn ṣe ń grow order ló ṣe jẹ́ kó gain more understanding
# [NeMo I 2025-01-31 17:56:10 wer:329]
#
# [NeMo I 2025-01-31 17:56:10 wer:330] reference:there is usually peace ni opolopo igba ti eniyan ba ni money lowo
# [NeMo I 2025-01-31 17:56:10 wer:331] predicted:there is usually peace ni opolopoop ti eniyan ba ni mor lowo
# [NeMo I 2025-01-31 17:56:10 wer:329]
#
# [NeMo I 2025-01-31 17:56:10 wer:330] reference:charge it to my card o better ju cash
# [NeMo I 2025-01-31 17:56:10 wer:331] predicted:charge to my card o better ju cash
# [NeMo I 2025-01-31 17:56:10 wer:329]
#
# [NeMo I 2025-01-31 17:56:10 wer:330] reference:emi na tun wa happy song yen ni effect
# [NeMo I 2025-01-31 17:56:10 wer:331] predicted:emi na tun wa happy song yẹn ni effect
# [NeMo I 2025-01-31 17:56:10 wer:329]
#
# [NeMo I 2025-01-31 17:56:10 wer:330] reference:informant mi so pe girl yen lo fun white party that night
# [NeMo I 2025-01-31 17:56:10 wer:331] predicted:informant mi so pe girl yen lo fun white party that night
# [NeMo I 2025-01-31 17:56:11 wer:329]
#
# [NeMo I 2025-01-31 17:56:11 wer:330] reference:mi o gbadun de gbogbo level tó fe ma play pelu mi at all
# [NeMo I 2025-01-31 17:56:11 wer:331] predicted:mi o gbadun de gbogbo level tó fe ma play pelu mi at all
# [NeMo I 2025-01-31 17:56:11 wer:329]
#
# [NeMo I 2025-01-31 17:56:11 wer:330] reference:i want to drink àgbo jẹ̀díjẹ̀dí
# [NeMo I 2025-01-31 17:56:11 wer:331] predicted:i want to drink àgbo jẹ̀díjẹ̀dí
# [NeMo I 2025-01-31 17:56:11 wer:329]
#
# [NeMo I 2025-01-31 17:56:11 wer:330] reference:kilo je ko miss class this morning traffic
# [NeMo I 2025-01-31 17:56:11 wer:331] predicted:kilo je comm miss classester morning traffic
# [NeMo I 2025-01-31 17:56:11 wer:329]
#
# [NeMo I 2025-01-31 17:56:11 wer:330] reference:wa gba water bottle ensure you hydrate often
# [NeMo I 2025-01-31 17:56:11 wer:331] predicted:wa gba water bottle ensure you hydrate often
# [NeMo I 2025-01-31 17:56:11 wer:329]
#
# [NeMo I 2025-01-31 17:56:11 wer:330] reference:i saw you when you came in lojo ajodun osu tuntun
# [NeMo I 2025-01-31 17:56:11 wer:331] predicted:i saw you when you came me lojojood osu tutunu
# [NeMo I 2025-01-31 17:56:11 wer:329]
#
# [NeMo I 2025-01-31 17:56:11 wer:330] reference:i have not taken my bath laaro yii
# [NeMo I 2025-01-31 17:56:11 wer:331] predicted:i have not taken my bath laaro
# [NeMo I 2025-01-31 17:56:11 wer:329]
#
# [NeMo I 2025-01-31 17:56:11 wer:330] reference:government ma ti yo subsidy lori petrol
# [NeMo I 2025-01-31 17:56:11 wer:331] predicted:government ma ti yo subsidy lori petrol
# [NeMo I 2025-01-31 17:56:11 wer:329]
#
# [NeMo I 2025-01-31 17:56:11 wer:330] reference:don’t play with iwe kika
# [NeMo I 2025-01-31 17:56:11 wer:331] predicted:donn’t play with iwe kika
# [NeMo I 2025-01-31 17:56:11 wer:329]
#
# [NeMo I 2025-01-31 17:56:11 wer:330] reference:mo wa impressed with the election results
# [NeMo I 2025-01-31 17:56:11 wer:331] predicted:mo wa impressed with the election results
# [NeMo I 2025-01-31 17:56:12 wer:329]
#
# [NeMo I 2025-01-31 17:56:12 wer:330] reference:mo gbo pe webinar on tech trend ma hold tonight
# [NeMo I 2025-01-31 17:56:12 wer:331] predicted:mo gbo pe webinar on tech trend ma hold tomonight
# [NeMo I 2025-01-31 17:56:12 wer:329]
#
# [NeMo I 2025-01-31 17:56:12 wer:330] reference:housework àti child training ni iṣẹ́ ti àwọn mothers nígbà yẹn
# [NeMo I 2025-01-31 17:56:12 wer:331] predicted:housework àti child trining ni iṣẹ́ tí awon mothers nígbà yẹn
# [NeMo I 2025-01-31 17:56:12 wer:329]
#
# [NeMo I 2025-01-31 17:56:12 wer:330] reference:lo já ewé efinrin fun mi i want to make pepeersoup
# [NeMo I 2025-01-31 17:56:12 wer:331] predicted:lọ j eereé ef mi fún mi i want to make pepper soup
# [NeMo I 2025-01-31 17:56:12 wer:329]
#
# [NeMo I 2025-01-31 17:56:12 wer:330] reference:obirin to fine ko dabi obirin to ni wa
# [NeMo I 2025-01-31 17:56:12 wer:331] predicted:obin to fine ko dabi obirin to ni wa
# [NeMo I 2025-01-31 17:56:12 wer:329]
#
# [NeMo I 2025-01-31 17:56:12 wer:330] reference:mo need cream yen ti o ni coconut oil inside
# [NeMo I 2025-01-31 17:56:12 wer:331] predicted:mo need s cream yen ti o ni coconut oil inside
# [NeMo I 2025-01-31 17:56:12 wer:329]
#
# [NeMo I 2025-01-31 17:56:12 wer:330] reference:wa je ki n copy notes yen fun tomorrow’s test
# [NeMo I 2025-01-31 17:56:12 wer:331] predicted:wao je ki n copy notes yen fun tomen’s test
# [NeMo I 2025-01-31 17:56:12 wer:329]
#
# [NeMo I 2025-01-31 17:56:12 wer:330] reference:ọ̀fẹ́ ni mo gba àwọn bags náà
# [NeMo I 2025-01-31 17:56:12 wer:331] predicted:ọ̀fẹ́ ni mo gba àwọn bags náà
# [NeMo I 2025-01-31 17:56:13 wer:329]
#
# [NeMo I 2025-01-31 17:56:13 wer:330] reference:tí ó bá n lọ sí ibi ìṣe try to avoid flashy makeup
# [NeMo I 2025-01-31 17:56:13 wer:331] predicted:tí ó bá n lọ sí ibiṣ try to avoid fashy makeup
# [NeMo I 2025-01-31 17:56:13 wer:329]
#
# [NeMo I 2025-01-31 17:56:13 wer:330] reference:ìkà ni búnmí ṣé o lè believe that she put chewing gum on my chair when we were small and i sat in it
# [NeMo I 2025-01-31 17:56:13 wer:331] predicted:ik ni bu mi ṣé o lè believe that she put ching gor on my chair when we e small and i sart on it
# [NeMo I 2025-01-31 17:56:13 wer:329]
#
# [NeMo I 2025-01-31 17:56:13 wer:330] reference:packing gel tí mo ṣe lọ ja irun iwájú mi
# [NeMo I 2025-01-31 17:56:13 wer:331] predicted:pa k jọ́ tí mo ṣe ló j irunwájú r
# [NeMo I 2025-01-31 17:56:13 wer:329]
#
# [NeMo I 2025-01-31 17:56:13 wer:330] reference:there are a lot of idagbasoke ilo ede yoruba on the knowledge of science
# [NeMo I 2025-01-31 17:56:13 wer:331] predicted:there are a lot of addagbsasoke e ilu ede yoruba on the knowledge of science
# [NeMo I 2025-01-31 17:56:13 wer:329]
#
# [NeMo I 2025-01-31 17:56:13 wer:330] reference:i saw a pẹ́pẹ́yẹ with nine ọmọ behind it
# [NeMo I 2025-01-31 17:56:13 wer:331] predicted:i saw a peẹ́pẹ́yẹ with nine ọmọ behind it
# [NeMo I 2025-01-31 17:56:13 wer:329]
#
# [NeMo I 2025-01-31 17:56:13 wer:330] reference:ẹ̀yọ̀gẹ̀lẹ̀dẹ́ and eégún are the traditional festivals that i love the most
# [NeMo I 2025-01-31 17:56:13 wer:331] predicted:eyin glẹ̀d and iqu ati traditional festivals are i e allw the most
# [NeMo I 2025-01-31 17:56:13 wer:329]
#
# [NeMo I 2025-01-31 17:56:13 wer:330] reference:nígbà tí mo lọ sí club a red wine spilled on her dress and ruined it
# [NeMo I 2025-01-31 17:56:13 wer:331] predicted:neigbà tí mo lọ sí cloth a red wlle spilled on her dress and run et
# [NeMo I 2025-01-31 17:56:14 wer:329]
#
# [NeMo I 2025-01-31 17:56:14 wer:330] reference:he raped her ni ana
# [NeMo I 2025-01-31 17:56:14 wer:331] predicted:he rp dá ni ana
# [NeMo I 2025-01-31 17:56:14 wer:329]
#
# [NeMo I 2025-01-31 17:56:14 wer:330] reference:three cars lo taku si egbe opopona
# [NeMo I 2025-01-31 17:56:14 wer:331] predicted:3ree cars lo tairk said gbee opopona
# [NeMo I 2025-01-31 17:56:14 wer:329]
#
# [NeMo I 2025-01-31 17:56:14 wer:330] reference:i have accepted jésù into my life
# [NeMo I 2025-01-31 17:56:14 wer:331] predicted:caness k you se to my life
# [NeMo I 2025-01-31 17:56:14 wer:329]
#
# [NeMo I 2025-01-31 17:56:14 wer:330] reference:ọ̀lẹ ni ọmọ yẹnfrom what i heard
# [NeMo I 2025-01-31 17:56:14 wer:331] predicted:ọ̀l ni ọmọ yẹnf from what i heard
# [NeMo I 2025-01-31 17:56:14 wer:329]
#
# [NeMo I 2025-01-31 17:56:14 wer:330] reference:aremu is an ọmọ bùjẹbùdànù
# [NeMo I 2025-01-31 17:56:14 wer:331] predicted:aremu is an ọmọ blujbleù danù
# [NeMo I 2025-01-31 17:56:14 wer:329]
#
# [NeMo I 2025-01-31 17:56:14 wer:330] reference:let me sin e de oju ona a little bit
# [NeMo I 2025-01-31 17:56:14 wer:331] predicted:let me yen de ojúina a little bit
# [NeMo I 2025-01-31 17:56:14 wer:329]
#
# [NeMo I 2025-01-31 17:56:14 wer:330] reference:thank you ti o ran mi leti
# [NeMo I 2025-01-31 17:56:14 wer:331] predicted:00 ti oan mi leti
# [NeMo I 2025-01-31 17:56:15 wer:329]
#
# [NeMo I 2025-01-31 17:56:15 wer:330] reference:i must wear a really pretty outfit for my birthday dinner mo gbódò yà àwọn pictures tó mà fín gan
# [NeMo I 2025-01-31 17:56:15 wer:331] predicted:i must wear a really pretty outfit for my birthday dinner ma gbdò y àwọn pictures tó mà fine wọn
# [NeMo I 2025-01-31 17:56:15 wer:329]
#
# [NeMo I 2025-01-31 17:56:15 wer:330] reference:they are inside ile igbonse
# [NeMo I 2025-01-31 17:56:15 wer:331] predicted:they are inside ile igbonse
# [NeMo I 2025-01-31 17:56:15 wer:329]
#
# [NeMo I 2025-01-31 17:56:15 wer:330] reference:my uncle says ‘ẹbí tó bá ní ètò yóò máa tẹ̀síwájú
# [NeMo I 2025-01-31 17:56:15 wer:331] predicted:my uncle says ‘ẹbí tó bá ní ètò yóò máa tẹ̀síwájú
# [NeMo I 2025-01-31 17:56:15 wer:329]
#
# [NeMo I 2025-01-31 17:56:15 wer:330] reference:jo bami fi rag clean up gbogbo cooler yèn
# [NeMo I 2025-01-31 17:56:15 wer:331] predicted:ìjọbami faract cleana puropcular
# [NeMo I 2025-01-31 17:56:15 wer:329]
#
# [NeMo I 2025-01-31 17:56:15 wer:330] reference:pick an asoju laarin yin
# [NeMo I 2025-01-31 17:56:15 wer:331] predicted:pick an asojuularin
# [NeMo I 2025-01-31 17:56:15 wer:329]
#
# [NeMo I 2025-01-31 17:56:15 wer:330] reference:is it possible pé kí n jẹ writer without reading books
# [NeMo I 2025-01-31 17:56:15 wer:331] predicted:is it possible pe kíin gener wrgher without reading books
# [NeMo I 2025-01-31 17:56:16 wer:329]
#
# [NeMo I 2025-01-31 17:56:16 wer:330] reference:the electric pole náà ti wó lulẹ̀
# [NeMo I 2025-01-31 17:56:16 wer:331] predicted:the electricle náà ti wo lul
# [NeMo I 2025-01-31 17:56:16 wer:329]
#
# [NeMo I 2025-01-31 17:56:16 wer:330] reference:the whole world should come and help us da si oro yii ko to polukurumusu
# [NeMo I 2025-01-31 17:56:16 wer:331] predicted:the whole wath pom and help us da si oro yi ko to pol kuru muusun
# [NeMo I 2025-01-31 17:56:16 wer:329]
#
# [NeMo I 2025-01-31 17:56:16 wer:330] reference:that celebrity’s belt ṣé ìwọ mọ̀ pé crocodile skin ni wọ́n fi ṣe
# [NeMo I 2025-01-31 17:56:16 wer:331] predicted:that celebrity’s belt se ìwokan pe ccia skin ni wọ́n fi se
# [NeMo I 2025-01-31 17:56:16 wer:329]
#
# [NeMo I 2025-01-31 17:56:16 wer:330] reference:teacher yen o ko wa enough
# [NeMo I 2025-01-31 17:56:16 wer:331] predicted:teacher yen o ko wa enough
# [NeMo I 2025-01-31 17:56:16 wer:329]
#
# [NeMo I 2025-01-31 17:56:16 wer:330] reference:the traders ò tíì arrive
# [NeMo I 2025-01-31 17:56:16 wer:331] predicted:kí trader ó tí arrive
# [NeMo I 2025-01-31 17:56:16 wer:329]
#
# [NeMo I 2025-01-31 17:56:16 wer:330] reference:my very good friend ki lo fe ki a fun e je
# [NeMo I 2025-01-31 17:56:16 wer:331] predicted:my very good friend ki lo fe ki a fun e je
# [NeMo I 2025-01-31 17:56:16 wer:329]
#
# [NeMo I 2025-01-31 17:56:16 wer:330] reference:i am not joking ododo oro ni mo n so fun yin
# [NeMo I 2025-01-31 17:56:16 wer:331] predicted:i not joking odododo oro ni won n so fun yin
# [NeMo I 2025-01-31 17:56:17 wer:329]
#
# [NeMo I 2025-01-31 17:56:17 wer:330] reference:why do you have so much ìkáàánú for me like that
# [NeMo I 2025-01-31 17:56:17 wer:331] predicted:why do you have so much àkánnu for me like that
# [NeMo I 2025-01-31 17:56:17 wer:329]
#
# [NeMo I 2025-01-31 17:56:17 wer:330] reference:mo ma go to abuja ni osu kesaan
# [NeMo I 2025-01-31 17:56:17 wer:331] predicted:mo mà go to abu journe ni osu kesau
# [NeMo I 2025-01-31 17:56:17 wer:329]
#
# [NeMo I 2025-01-31 17:56:17 wer:330] reference:we always pray together as a family because ‘àdúrà ni kí a máa ṣe’
# [NeMo I 2025-01-31 17:56:17 wer:331] predicted:we always pray together as a family because ‘àdúrà ni chá má ṣe
# [NeMo I 2025-01-31 17:56:17 wer:329]
#
# [NeMo I 2025-01-31 17:56:17 wer:330] reference:favourite subject mi ni agriculture
# [NeMo I 2025-01-31 17:56:17 wer:331] predicted:favourite subject mi ni agricultureal
# [NeMo I 2025-01-31 17:56:17 wer:329]
#
# [NeMo I 2025-01-31 17:56:17 wer:330] reference:we believe ‘ẹbí ni ìpilẹ̀gbogbo ayé’”
# [NeMo I 2025-01-31 17:56:17 wer:331] predicted:we believe ‘ẹbí ni ẹbíil gbogbo ayé
# [NeMo I 2025-01-31 17:56:17 wer:329]
#
# [NeMo I 2025-01-31 17:56:17 wer:330] reference:bàbá yárí wípé he doesn’t want injections
# [NeMo I 2025-01-31 17:56:17 wer:331] predicted:bàbá yárí wípé he doesn’t want injections
# [NeMo I 2025-01-31 17:56:17 wer:329]
#
# [NeMo I 2025-01-31 17:56:17 wer:330] reference:i love spending time with my cousins because ‘ko ò sí ẹbí tó dá bí ẹbí ọmọdé
# [NeMo I 2025-01-31 17:56:17 wer:331] predicted:i love spending time with my cousin because ‘kò sí ẹbí tó dá bí ẹbí ọmọdé
# [NeMo I 2025-01-31 17:56:17 wer:329]
#
# [NeMo I 2025-01-31 17:56:17 wer:330] reference:the defendant ti argue pé wọn kò violate àwọn terms ti contract náà
# [NeMo I 2025-01-31 17:56:17 wer:331] predicted:ti defendant ti argue pé wọn kò violate àwọn terms ti contract náà
# [NeMo I 2025-01-31 17:56:17 wer:329]
#
# [NeMo I 2025-01-31 17:56:17 wer:330] reference:always prevent ara ẹ̀ from injuries
# [NeMo I 2025-01-31 17:56:17 wer:331] predicted:always prevent ara ẹ̀ from injues
# [NeMo I 2025-01-31 17:56:18 wer:329]
#
# [NeMo I 2025-01-31 17:56:18 wer:330] reference:my mother always says ‘ẹbí tó bá ní àlàáfíà yóò gbé ilé rẹ̀sókè
# [NeMo I 2025-01-31 17:56:18 wer:331] predicted:my mother always says ‘ẹbí tó bá ní àlàáfíà yóò gbé ilé rsókè
# [NeMo I 2025-01-31 17:56:18 wer:329]
#
# [NeMo I 2025-01-31 17:56:18 wer:330] reference:she reads very slow bi igbin
# [NeMo I 2025-01-31 17:56:18 wer:331] predicted:she reads very slow bi ibíin
# [NeMo I 2025-01-31 17:56:18 wer:329]
#
# [NeMo I 2025-01-31 17:56:18 wer:330] reference:dọkítà sọpé we should reduce our sugar intake level
# [NeMo I 2025-01-31 17:56:18 wer:331] predicted:dọkítà sọpé we should reduce our sugar intake level
# [NeMo I 2025-01-31 17:56:18 wer:329]
#
# [NeMo I 2025-01-31 17:56:18 wer:330] reference:my siblings and i play together because ‘ìrẹ́pọ̀ọmọ ilé ń mú ìgbésí ayé dùn
# [NeMo I 2025-01-31 17:56:18 wer:331] predicted:my siblings and i play together because ‘ìrẹ́pọ̀mọ ilé ń mú ìgbésí ayé dùn
# [NeMo I 2025-01-31 17:56:18 wer:329]
#
# [NeMo I 2025-01-31 17:56:18 wer:330] reference:you must go to iyara ikawe
# [NeMo I 2025-01-31 17:56:18 wer:331] predicted:you must go to iyara ikawe
# [NeMo I 2025-01-31 17:56:18 wer:329]
#
# [NeMo I 2025-01-31 17:56:18 wer:330] reference:ọjọ́ tí wọ́n yóò conduct crossexamination tí key witness ti confirm lónìí
# [NeMo I 2025-01-31 17:56:18 wer:331] predicted:jọ́ tí wọ́n yóò conduct crossexination ti key witness ti confirm loi
# [NeMo I 2025-01-31 17:56:18 wer:329]
#
# [NeMo I 2025-01-31 17:56:18 wer:330] reference:mo pass exam mi
# [NeMo I 2025-01-31 17:56:18 wer:331] predicted:mo pass exam mi
# [NeMo I 2025-01-31 17:56:18 wer:329]
#
# [NeMo I 2025-01-31 17:56:18 wer:330] reference:i’m interested ninu topic yen
# [NeMo I 2025-01-31 17:56:18 wer:331] predicted:ien’m interested in topic yen
# [NeMo I 2025-01-31 17:56:19 wer:329]
#
# [NeMo I 2025-01-31 17:56:19 wer:330] reference:educational system yii slow gan we are supposed to be in year 4
# [NeMo I 2025-01-31 17:56:19 wer:331] predicted:educational system yii slow gan we are supposed to be in year 4
# [NeMo I 2025-01-31 17:56:19 wer:329]
#
# [NeMo I 2025-01-31 17:56:19 wer:330] reference:ile iwe should prioritize mental health for akeko
# [NeMo I 2025-01-31 17:56:19 wer:331] predicted:ile iwe should prioritize mental health for akeko
# [NeMo I 2025-01-31 17:56:19 wer:329]
#
# [NeMo I 2025-01-31 17:56:19 wer:330] reference:ti government o ba increase minimum wagesworkers will strike
# [NeMo I 2025-01-31 17:56:19 wer:331] predicted:ti government to ba n increase minimum wageswkers will strike
# [NeMo I 2025-01-31 17:56:19 wer:329]
#
# [NeMo I 2025-01-31 17:56:19 wer:330] reference:she left ile iwe yesterday
# [NeMo I 2025-01-31 17:56:19 wer:331] predicted:she left ile iwe yesterday
# [NeMo I 2025-01-31 17:56:19 wer:329]
#
# [NeMo I 2025-01-31 17:56:19 wer:330] reference:mọ gba sixtyeight percent ní ìdánwò wá
# [NeMo I 2025-01-31 17:56:19 wer:331] predicted:mọ gba ty4ight0 ní ìdọ́wòwọ́ wá
# [NeMo I 2025-01-31 17:56:19 wer:329]
#
# [NeMo I 2025-01-31 17:56:19 wer:330] reference:you must buy your calculator ni ola
# [NeMo I 2025-01-31 17:56:19 wer:331] predicted:you must buy your calculor ni ola
# [NeMo I 2025-01-31 17:56:19 wer:329]
#
# [NeMo I 2025-01-31 17:56:19 wer:330] reference:mọ fẹ́ fo bata school mí
# [NeMo I 2025-01-31 17:56:19 wer:331] predicted:mo fẹ́ fo bata school mi
# [NeMo I 2025-01-31 17:56:19 wer:329]
#
# [NeMo I 2025-01-31 17:56:19 wer:330] reference:se o ti de office governor ri so fine
# [NeMo I 2025-01-31 17:56:19 wer:331] predicted:se o ti de office governor ri so fine
# [NeMo I 2025-01-31 17:56:19 wer:329]
#
# [NeMo I 2025-01-31 17:56:19 wer:330] reference:oko mi ra louis vuitton bag fun ayeye odun kerin wedding anniversary wa
# [NeMo I 2025-01-31 17:56:19 wer:331] predicted:ọko mi ra lose viton bag fun ayeo dkerrin wedding anniversary wa
# [NeMo I 2025-01-31 17:56:20 wer:329]
#
# [NeMo I 2025-01-31 17:56:20 wer:330] reference:so ti ri new roundabout ti governor sese contruct
# [NeMo I 2025-01-31 17:56:20 wer:331] predicted:se o ti ri new roundabout ti governor sese contruct
# [NeMo I 2025-01-31 17:56:20 wer:329]
#
# [NeMo I 2025-01-31 17:56:20 wer:330] reference:lo spread iwe yen
# [NeMo I 2025-01-31 17:56:20 wer:331] predicted:lo spread iwe yen
# [NeMo I 2025-01-31 17:56:20 wer:329]
#
# [NeMo I 2025-01-31 17:56:20 wer:330] reference:government officials n ṣe ìtẹ̀júwò ní gbogbo ìpínlẹ̀
# [NeMo I 2025-01-31 17:56:20 wer:331] predicted:government officials n ṣe tjúwò ní gbogbo ìpínlẹ̀ẹ̀
# [NeMo I 2025-01-31 17:56:20 wer:329]
#
# [NeMo I 2025-01-31 17:56:20 wer:330] reference:civil servants want promotion won ti fe protest
# [NeMo I 2025-01-31 17:56:20 wer:331] predicted:civil servant want promotionwon ti fa protest
# [NeMo I 2025-01-31 17:56:20 wer:329]
#
# [NeMo I 2025-01-31 17:56:20 wer:330] reference:education system must adapt si changing needs awujo wa
# [NeMo I 2025-01-31 17:56:20 wer:331] predicted:education system must adastt si changing needs awujo wa
# [NeMo I 2025-01-31 17:56:20 wer:329]
#
# [NeMo I 2025-01-31 17:56:20 wer:330] reference:awon government sese plant new flowers si state house noni
# [NeMo I 2025-01-31 17:56:20 wer:331] predicted:awon government sese plant new flowers si state house loni
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │        global_step        │          32820.0          │
# │         test_loss         │    1.0643792152404785     │
# │         test_wer          │    0.2962435185909271     │
# └───────────────────────────┴───────────────────────────┘
# [{'global_step': 32820.0, 'test_loss': 1.0643792152404785, 'test_wer': 0.2962435185909271}]

# %%
import wandb

# Log test results
wandb.log({
    "global_step":results[0]["global_step"],
    "test_loss": results[0]["test_loss"],  # Adjust key name based on output
    "test_wer": results[0]["test_wer"]  # Adjust key name based on output
})

print("Test results logged to W&B successfully!")
# Out:
# Test results logged to W&B successfully!

# %%
pretrained_model.save_to("saved_model/fine_tuned_model.nemo")
print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
import shutil

tokenizer_dir = "tokenizers/codeswitched_tokenizer"
saved_tokenizer_dir = "saved_model/tokenizer"

# Copy the tokenizer files to a new directory
shutil.copytree(tokenizer_dir, saved_tokenizer_dir)
print(f"Tokenizer saved to {saved_tokenizer_dir}")
# Out:
# Tokenizer saved to saved_model/tokenizer
